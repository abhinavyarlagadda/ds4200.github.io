# %%
import pandas as pd
import numpy as np
import requests
import json
from collections import defaultdict

# %%
EMAIL = 'jmeiwb20@gmail.com'
KEY = 'mauvemouse78'
MA = '25'

# %%
counties_response = requests.get(f"https://aqs.epa.gov/data/api/list/countiesByState?email={EMAIL}&key={KEY}&state={MA}")
counties = counties_response.json()
counties
# Out:
# {'Header': [{'status': 'Success',
#    'request_time': '2026-03-29T14:00:02-04:00',
#    'url': 'https://aqs.epa.gov/data/api/list/countiesByState?email=jmeiwb20@gmail.com&key=mauvemouse78&state=25',
#    'rows': 14}],
#  'Data': [{'code': '001', 'value_represented': 'Barnstable'},
#   {'code': '003', 'value_represented': 'Berkshire'},
#   {'code': '005', 'value_represented': 'Bristol'},
#   {'code': '007', 'value_represented': 'Dukes'},
#   {'code': '009', 'value_represented': 'Essex'},
#   {'code': '011', 'value_represented': 'Franklin'},
#   {'code': '013', 'value_represented': 'Hampden'},
#   {'code': '015', 'value_represented': 'Hampshire'},
#   {'code': '017', 'value_represented': 'Middlesex'},
#   {'code': '019', 'value_represented': 'Nantucket'},
#   {'code': '021', 'value_represented': 'Norfolk'},
#   {'code': '023', 'value_represented': 'Plymouth'},
#   {'code': '025', 'value_represented': 'Suffolk'},
#   {'code': '027', 'value_represented': 'Worcester'}]}

# %%
bc_response = requests.get(f"https://aqs.epa.gov/data/api/monitors/byCounty?email={EMAIL}&key={KEY}&param=88502&bdate=20150501&edate=20150502&state={MA}&county=001")
bc = bc_response.json()
bc
# Out:
# {'Header': [{'status': 'Success',
#    'request_time': '2026-03-29T14:00:02-04:00',
#    'url': 'https://aqs.epa.gov/data/api/monitors/byCounty?email=jmeiwb20@gmail.com&key=mauvemouse78&param=88502&bdate=20150501&edate=20150502&state=25&county=001',
#    'rows': 1}],
#  'Data': [{'state_code': '25',
#    'county_code': '001',
#    'site_number': '0002',
#    'parameter_code': '88502',
#    'poc': 1,
#    'parameter_name': 'Acceptable PM2.5 AQI & Speciation Mass',
#    'open_date': '2001-04-04',
#    'close_date': None,
#    'concurred_exclusions': None,
#    'dominant_source': None,
#    'measurement_scale': 'REGIONAL SCALE',
#    'measurement_scale_def': '50 TO HUNDREDS KM',
#    'monitoring_objective': 'GENERAL/BACKGROUND',
#    'last_method_code': '707',
#    'last_method_description': 'IMPROVE Module A with Cyclone Inlet-Teflon Filter, 2.2 sq. cm. - GRAVIMETRIC',
#    'last_method_begin_date': '2001-04-04',
#    'naaqs_primary_monitor': None,
#    'qa_primary_monitor': None,
#    'monitor_type': 'EPA',
#    'networks': 'IMPROVE',
#    'monitoring_agency_code': '0745',
#    'monitoring_agency': 'National Park Service',
#    'si_id': 6931,
#    'latitude': 41.975804,
#    'longitude': -70.023598,
#    'datum': 'WGS84',
#    'lat_lon_accuracy': 30.36,
#    'elevation': 41.0,
#    'probe_height': None,
#    'pl_probe_location': None,
#    'local_site_name': 'TRURO NATIONAL SEASHORE',
#    'address': 'FOX BOTTOM AREA',
#    'state_name': 'Massachusetts',
#    'county_name': 'Barnstable',
#    'city_name': 'Truro',
#    'cbsa_code': '12700',
#    'cbsa_name': 'Barnstable Town, MA',
#    'csa_code': '148',
#    'csa_name': 'Boston-Worcester-Providence, MA-RI-NH-CT',
#    'tribal_code': None,
#    'tribe_name': None}]}

# %%
conc = pd.read_csv("annual_conc_by_monitor_2025.csv")

# %%
conc.head()
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1            3        10           44201    1  30.497478
# 1           1            3        10           44201    1  30.497478
# 2           1            3        10           44201    1  30.497478
# 3           1            3        10           44201    1  30.497478
# 4           1            3        10           88101    3  30.497478
#
#    Longitude  Datum            Parameter Name          Sample Duration  ...  \
# 0 -87.880258  NAD83                     Ozone                   1 HOUR  ...
# 1 -87.880258  NAD83                     Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 2 -87.880258  NAD83                     Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 3 -87.880258  NAD83                     Ozone  8-HR RUN AVG BEGIN HOUR  ...
# 4 -87.880258  NAD83  PM2.5 - Local Conditions                   1 HOUR  ...
#
#   75th Percentile 50th Percentile 10th Percentile    Local Site Name  \
# 0           0.054           0.045           0.029  FAIRHOPE, Alabama
# 1           0.049           0.040           0.026  FAIRHOPE, Alabama
# 2           0.049           0.040           0.026  FAIRHOPE, Alabama
# 3           0.049           0.040           0.026  FAIRHOPE, Alabama
# 4          10.000           6.000           1.000  FAIRHOPE, Alabama
#
#                                              Address State Name  County Name  \
# 0  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama      Baldwin
# 1  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama      Baldwin
# 2  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama      Baldwin
# 3  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama      Baldwin
# 4  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...    Alabama      Baldwin
#
#    City Name                  CBSA Name  Date of Last Change
# 0   Fairhope  Daphne-Fairhope-Foley, AL           2025-10-29
# 1   Fairhope  Daphne-Fairhope-Foley, AL           2025-10-29
# 2   Fairhope  Daphne-Fairhope-Foley, AL           2025-10-29
# 3   Fairhope  Daphne-Fairhope-Foley, AL           2025-10-29
# 4   Fairhope  Daphne-Fairhope-Foley, AL           2025-10-29
#
# [5 rows x 55 columns]

# %%
pollutants_tested = conc[["Local Site Name", "Parameter Name", "State Name"]]

# %%
tested = defaultdict(dict)
for state in list(set(conc['State Name'])):
    state_df = conc[conc["State Name"] == state]
    for site in list(set(state_df[['Local Site Name']])):
        site_df = state_df[state_df["Local Site Name"] == site]
        params = set(site_df['Parameter Name'])
        tested[state][site] = params

# %%
tested = defaultdict(dict)
for i in list(set(conc['State Name'])):
    state_df = conc[conc["State Name"] == i]
    for j in list(set(state_df['Local Site Name'])):
        site_df = state_df[state_df["Local Site Name"] == j]
        params = set(site_df['Parameter Name'])
        tested[i][j] = params

# %%
conc.columns
# Out:
# Index(['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Sample Duration',
#        'Pollutant Standard', 'Metric Used', 'Method Name', 'Year',
#        'Units of Measure', 'Event Type', 'Observation Count',
#        'Observation Percent', 'Completeness Indicator', 'Valid Day Count',
#        'Required Day Count', 'Exceptional Data Count', 'Null Data Count',
#        'Primary Exceedance Count', 'Secondary Exceedance Count',
#        'Certification Indicator', 'Num Obs Below MDL', 'Arithmetic Mean',
#        'Arithmetic Standard Dev', '1st Max Value', '1st Max DateTime',
#        '2nd Max Value', '2nd Max DateTime', '3rd Max Value',
#        '3rd Max DateTime', '4th Max Value', '4th Max DateTime',
#        '1st Max Non Overlapping Value', '1st NO Max DateTime',
#        '2nd Max Non Overlapping Value', '2nd NO Max DateTime',
#        '99th Percentile', '98th Percentile', '95th Percentile',
#        '90th Percentile', '75th Percentile', '50th Percentile',
#        '10th Percentile', 'Local Site Name', 'Address', 'State Name',
#        'County Name', 'City Name', 'CBSA Name', 'Date of Last Change'],
#       dtype='object')

# %%
conc["Observation Count"]
# Out:
# 0        4141
# 1        4328
# 2        4328
# 3        3071
# 4        5780
#          ...
# 59149     224
# 59150    6277
# 59151    6547
# 59152    6547
# 59153    4636
# Name: Observation Count, Length: 59154, dtype: int64

# %%
tested
# Out:
# defaultdict(dict,
#             {'Minnesota': {'Brainerd Lakes Regional Airport': {'Ozone',
#                'PM2.5 - Local Conditions'},
#               'Ramsey Health Center': {'Ambient Max Temperature',
#                'Ambient Min Temperature',
#                'Average Ambient Pressure',
#                'Average Ambient Temperature',
#                'Elapsed Sample Time',
#                'PM10 Total 0-10um STP',
#                'PM2.5 - Local Conditions',
#                'Sample Flow Rate- CV',
#                'Sample Max Baro Pressure',
#                'Sample Min Baro Pressure',
#                'Sample Volume'},
#               'Rosa Parks Elementary': {'Ozone', 'PM2.5 - Local Conditions'},
#               'U of M - Duluth': {'Ozone', 'PM2.5 - Local Conditions'},
#               'Stanton Air Field': {'Ozone'},
#               'Hennepin Center for the Arts': {'Carbon monoxide',
#                'SO2 max 5-min avg',
#                'Sulfur dioxide'},
#               'B.F. Pearson School': {'Ozone', 'PM2.5 - Local Conditions'},
#               'Fond du Lac Band': {'Ozone', 'PM2.5 - Local Conditions'},
#               'FWS Wetland Management District': {'Ozone',
#                'PM2.5 - Local Conditions'},
#               'Flint Hills Refinery 443': {'SO2 max 5-min avg',
#                'Sulfur dioxide'},
#               'Lowry Avenue': {'Arsenic (TSP) LC',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Chromium (TSP) LC',
#                'Lead (TSP) LC',
#                'Manganese (TSP) LC',
#                'Nickel (TSP) LC',
#                'Selenium (TSP) LC',
#                'Suspended particulate (TSP)',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant'},
#               'Flint Hills Refinery 423': {'Arsenic (TSP) LC',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Carbon monoxide',
#                'Chromium (TSP) LC',
#                'Lead (TSP) LC',
#                'Manganese (TSP) LC',
#                'Nickel (TSP) LC',
#                'Nitric oxide (NO)',
#                'Nitrogen dioxide (NO2)',
#                'Oxides of nitrogen (NOx)',
#                'SO2 max 5-min avg',
#                'Selenium (TSP) LC',
#                'Sulfur dioxide',
#                'Suspended particulate (TSP)',
#                'Total reduced sulfur',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant',
#                'Wind Speed - Scalar'},
#               'Waseca Road': {'Arsenic (TSP) LC',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Chromium (TSP) LC',
#                'Lead (TSP) LC',
#                'Manganese (TSP) LC',
#                'Nickel (TSP) LC',
#                'Selenium (TSP) LC',
#                'Suspended particulate (TSP)'},
#               'Greenway Neighborhood': {'Arsenic (TSP) LC',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Chromium (TSP) LC',
#                'Lead (TSP) LC',
#                'Manganese (TSP) LC',
#                'Nickel (TSP) LC',
#                'PM2.5 - Local Conditions',
#                'Selenium (TSP) LC',
#                'Suspended particulate (TSP)',
#                'Wind Speed - Resultant'},
#               nan: set(),
#               'Great River Bluffs': {'Acceptable PM2.5 AQI & Speciation Mass',
#                'Aluminum PM2.5 LC',
#                'Ammonium Nitrate PM2.5 LC',
#                'Ammonium Sulfate PM2.5 LC',
#                'Arsenic PM2.5 LC',
#                'Bromine PM2.5 LC',
#                'Calcium PM2.5 LC',
#                'Chloride PM2.5 LC',
#                'Chlorine PM2.5 LC',
#                'Chromium PM2.5 LC',
#                'Copper PM2.5 LC',
#                'EC PM2.5 LC TOR',
#                'EC1 PM2.5 LC',
#                'EC2 PM2.5 LC',
#                'EC3 PM2.5 LC',
#                'Iron PM2.5 LC',
#                'Lead PM2.5 LC',
#                'Light Absorption Coeffiecient',
#                'Magnesium PM2.5 LC',
#                'Manganese PM2.5 LC',
#                'Nickel PM2.5 LC',
#                'Nitrite PM2.5 LC',
#                'OC PM2.5 LC TOR',
#                'OC1 PM2.5 LC',
#                'OC2 PM2.5 LC',
#                'OC3 PM2.5 LC',
#                'OC4 PM2.5 LC',
#                'OP PM2.5 LC TOR',
#                'Organic Carbon Mass PM2.5 LC',
#                'PM10 - LC',
#                'PM10-2.5 - Local Conditions',
#                'Phosphorus PM2.5 LC',
#                'Potassium PM2.5 LC',
#                'Rubidium PM2.5 LC',
#                'Selenium PM2.5 LC',
#                'Silicon PM2.5 LC',
#                'Sodium PM2.5 LC',
#                'Soil PM2.5 LC',
#                'Strontium PM2.5 LC',
#                'Sulfate PM2.5 LC',
#                'Sulfur PM2.5 LC',
#                'Titanium PM2.5 LC',
#                'Total Nitrate PM2.5 LC',
#                'Vanadium PM2.5 LC',
#                'Zinc PM2.5 LC',
#                'Zirconium PM2.5 LC'},
#               'St. Michael Elementary School': {'Ozone',
#                'PM2.5 - Local Conditions'},
#               'Pacific Street': {'Arsenic (TSP) LC',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Chromium (TSP) LC',
#                'Lead (TSP) LC',
#                'Manganese (TSP) LC',
#                'Nickel (TSP) LC',
#                'PM10 Total 0-10um STP',
#                'PM2.5 - Local Conditions',
#                'Selenium (TSP) LC',
#                'Suspended particulate (TSP)'},
#               'Anoka County Airport': {'Aluminum PM2.5 LC',
#                'Ambient Max Temperature',
#                'Ambient Min Temperature',
#                'Ammonium Ion PM2.5 LC',
#                'Antimony PM2.5 LC',
#                'Arsenic (TSP) LC',
#                'Arsenic PM2.5 LC',
#                'Average Ambient Pressure',
#                'Average Ambient Pressure for URG3000N',
#                'Average Ambient Temperature',
#                'Average Ambient Temperature for URG3000N',
#                'Barium PM2.5 LC',
#                'Beryllium (TSP) LC',
#                'Bromine PM2.5 LC',
#                'Cadmium (TSP) LC',
#                'Cadmium PM2.5 LC',
#                'Calcium PM2.5 LC',
#                'Carbon monoxide',
#                'Cerium PM2.5 LC',
#                'Cesium PM2.5 LC',
#                'Chloride PM2.5 LC',
#                'Chlorine PM2.5 LC',
#                'Chromium (TSP) LC',
#                'Chromium PM2.5 LC',
#                'Cobalt PM2.5 LC',
#                'Copper PM2.5 LC',
#                'EC CSN_Rev Unadjusted PM2.5 LC TOR',
#                'EC CSN_Rev Unadjusted PM2.5 LC TOT',
#                'EC PM2.5 LC TOR',
#                'EC PM2.5 LC TOT',
#                'EC1 CSN_Rev Unadjusted PM2.5 LC',
#                'EC1 PM2.5 LC',
#                'EC2 CSN_Rev Unadjusted PM2.5 LC',
#                'EC2 PM2.5 LC',
#                'EC3 CSN_Rev Unadjusted PM2.5 LC',
#                'EC3 PM2.5 LC',
#                'Elapsed Sample Time',
#                'Indium PM2.5 LC',
#                'Iron PM2.5 LC',
#                'Lead (TSP) LC',
#                'Lead PM2.5 LC',
#                'Light Absorption Coeffiecient',
#                'Magnesium PM2.5 LC',
#                'Manganese (TSP) LC',
#                'Manganese PM2.5 LC',
#                'NOy - NO',
#                'Nickel (TSP) LC',
#                'Nickel PM2.5 LC',
#                'Nitric oxide (NO)',
#                'Nitrogen dioxide (NO2)',
#                'OC CSN_Rev Unadjusted PM2.5 LC TOR',
#                'OC CSN_Rev Unadjusted PM2.5 LC TOT',
#                'OC PM2.5 LC TOR',
#                'OC PM2.5 LC TOT',
#                'OC1 CSN_Rev Unadjusted PM2.5 LC',
#                'OC1 PM2.5 LC',
#                'OC2 CSN_Rev Unadjusted PM2.5 LC',
#                'OC2 PM2.5 LC',
#                'OC3 CSN_Rev Unadjusted PM2.5 LC',
#                'OC3 PM2.5 LC',
#                'OC4 CSN_Rev Unadjusted PM2.5 LC',
#                'OC4 PM2.5 LC',
#                'OP CSN_Rev Unadjusted PM2.5 LC TOR',
#                'OP CSN_Rev Unadjusted PM2.5 LC TOT',
#                'OP PM2.5 LC TOR',
#                'OP PM2.5 LC TOT',
#                'Outdoor Temperature',
#                'Oxides of nitrogen (NOx)',
#                'Ozone',
#                'PM10 Total 0-10um STP',
#                'PM2.5 - Local Conditions',
#                'Phosphorus PM2.5 LC',
#                'Potassium Ion PM2.5 LC',
#                'Potassium PM2.5 LC',
#                'Reactive oxides of nitrogen (NOy)',
#                'Reconstructed Mass PM2.5 LC',
#                'Rubidium PM2.5 LC',
#                'SO2 max 5-min avg',
#                'Sample Flow Rate CV - Nylon Filter',
#                'Sample Flow Rate CV - Quartz Filter',
#                'Sample Flow Rate CV - Teflon Filter',
#                'Sample Flow Rate- CV',
#                'Sample Max Baro Pressure',
#                'Sample Min Baro Pressure',
#                'Sample Volume',
#                'Sample Volume - Nylon Filter',
#                'Sample Volume - Quartz Filter',
#                'Sample Volume - Teflon Filter',
#                'Selenium (TSP) LC',
#                'Selenium PM2.5 LC',
#                'Silicon PM2.5 LC',
#                'Silver PM2.5 LC',
#                'Sodium Ion Pm2.5 LC',
#                'Sodium PM2.5 LC',
#                'Soil PM2.5 LC',
#                'Strontium PM2.5 LC',
#                'Sulfate PM2.5 LC',
#                'Sulfur PM2.5 LC',
#                'Sulfur dioxide',
#                'Suspended particulate (TSP)',
#                'Tin PM2.5 LC',
#                'Titanium PM2.5 LC',
#                'Total Nitrate PM2.5 LC',
#                'Vanadium PM2.5 LC',
#                'Wind Direction - Resultant',
#                'Wind Direction - Scalar',
#                'Wind Speed - Resultant',
#                'Wind Speed - Scalar',
#                'Zinc PM2.5 LC',
#                'Zirconium PM2.5 LC'},
#               'Red Lake Nation DNR': {'Ozone'},
#               'City of Lakes Building': {'Arsenic (TSP) LC',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Chromium (TSP) LC',
#                'Lead (TSP) LC',
#                'Manganese (TSP) LC',
#                'Nickel (TSP) LC',
#                'PM10 Total 0-10um STP',
#                'Selenium (TSP) LC',
#                'Suspended particulate (TSP)'},
#               'Gopher Resources': {'Arsenic (TSP) LC',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Chromium (TSP) LC',
#                'Lead (TSP) LC',
#                'Manganese (TSP) LC',
#                'Nickel (TSP) LC',
#                'Selenium (TSP) LC',
#                'Suspended particulate (TSP)'},
#               'Newport City Hall': {'Arsenic (TSP) LC',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Chromium (TSP) LC',
#                'Lead (TSP) LC',
#                'Manganese (TSP) LC',
#                'Nickel (TSP) LC',
#                'Selenium (TSP) LC',
#                'Suspended particulate (TSP)'},
#               'Cedar Creek': {'Ozone'},
#               'Andersen School': {'Aluminum PM2.5 LC',
#                'Ambient Max Temperature',
#                'Ambient Min Temperature',
#                'Ammonium Ion PM2.5 LC',
#                'Antimony PM2.5 LC',
#                'Arsenic (TSP) LC',
#                'Arsenic PM2.5 LC',
#                'Average Ambient Pressure',
#                'Average Ambient Pressure for URG3000N',
#                'Average Ambient Temperature',
#                'Average Ambient Temperature for URG3000N',
#                'Barium PM2.5 LC',
#                'Beryllium (TSP) LC',
#                'Bromine PM2.5 LC',
#                'Cadmium (TSP) LC',
#                'Cadmium PM2.5 LC',
#                'Calcium PM2.5 LC',
#                'Cerium PM2.5 LC',
#                'Cesium PM2.5 LC',
#                'Chloride PM2.5 LC',
#                'Chlorine PM2.5 LC',
#                'Chromium (TSP) LC',
#                'Chromium PM2.5 LC',
#                'Cobalt PM2.5 LC',
#                'Copper PM2.5 LC',
#                'EC CSN_Rev Unadjusted PM2.5 LC TOR',
#                'EC CSN_Rev Unadjusted PM2.5 LC TOT',
#                'EC PM2.5 LC TOR',
#                'EC PM2.5 LC TOT',
#                'EC1 CSN_Rev Unadjusted PM2.5 LC',
#                'EC1 PM2.5 LC',
#                'EC2 CSN_Rev Unadjusted PM2.5 LC',
#                'EC2 PM2.5 LC',
#                'EC3 CSN_Rev Unadjusted PM2.5 LC',
#                'EC3 PM2.5 LC',
#                'Elapsed Sample Time',
#                'Indium PM2.5 LC',
#                'Iron PM2.5 LC',
#                'Lead (TSP) LC',
#                'Lead PM2.5 LC',
#                'Light Absorption Coeffiecient',
#                'Magnesium PM2.5 LC',
#                'Manganese (TSP) LC',
#                'Manganese PM2.5 LC',
#                'Nickel (TSP) LC',
#                'Nickel PM2.5 LC',
#                'OC CSN_Rev Unadjusted PM2.5 LC TOR',
#                'OC CSN_Rev Unadjusted PM2.5 LC TOT',
#                'OC PM2.5 LC TOR',
#                'OC PM2.5 LC TOT',
#                'OC1 CSN_Rev Unadjusted PM2.5 LC',
#                'OC1 PM2.5 LC',
#                'OC2 CSN_Rev Unadjusted PM2.5 LC',
#                'OC2 PM2.5 LC',
#                'OC3 CSN_Rev Unadjusted PM2.5 LC',
#                'OC3 PM2.5 LC',
#                'OC4 CSN_Rev Unadjusted PM2.5 LC',
#                'OC4 PM2.5 LC',
#                'OP CSN_Rev Unadjusted PM2.5 LC TOR',
#                'OP CSN_Rev Unadjusted PM2.5 LC TOT',
#                'OP PM2.5 LC TOR',
#                'OP PM2.5 LC TOT',
#                'PM2.5 - Local Conditions',
#                'Phosphorus PM2.5 LC',
#                'Potassium Ion PM2.5 LC',
#                'Potassium PM2.5 LC',
#                'Reconstructed Mass PM2.5 LC',
#                'Rubidium PM2.5 LC',
#                'Sample Flow Rate CV - Nylon Filter',
#                'Sample Flow Rate CV - Quartz Filter',
#                'Sample Flow Rate CV - Teflon Filter',
#                'Sample Flow Rate- CV',
#                'Sample Max Baro Pressure',
#                'Sample Min Baro Pressure',
#                'Sample Volume',
#                'Sample Volume - Nylon Filter',
#                'Sample Volume - Quartz Filter',
#                'Sample Volume - Teflon Filter',
#                'Selenium (TSP) LC',
#                'Selenium PM2.5 LC',
#                'Silicon PM2.5 LC',
#                'Silver PM2.5 LC',
#                'Sodium Ion Pm2.5 LC',
#                'Sodium PM2.5 LC',
#                'Soil PM2.5 LC',
#                'Strontium PM2.5 LC',
#                'Sulfate PM2.5 LC',
#                'Sulfur PM2.5 LC',
#                'Suspended particulate (TSP)',
#                'Tin PM2.5 LC',
#                'Titanium PM2.5 LC',
#                'Total Nitrate PM2.5 LC',
#                'Vanadium PM2.5 LC',
#                'Zinc PM2.5 LC',
#                'Zirconium PM2.5 LC'},
#               'Laura MacArthur School': {'PM2.5 - Local Conditions'},
#               'Apple Valley': {'PM2.5 - Local Conditions'},
#               'Boundary Waters': {'Acceptable PM2.5 AQI & Speciation Mass',
#                'Aluminum PM2.5 LC',
#                'Ammonium Nitrate PM2.5 LC',
#                'Ammonium Sulfate PM2.5 LC',
#                'Arsenic PM2.5 LC',
#                'Bromine PM2.5 LC',
#                'Calcium PM2.5 LC',
#                'Chloride PM2.5 LC',
#                'Chlorine PM2.5 LC',
#                'Chromium PM2.5 LC',
#                'Copper PM2.5 LC',
#                'EC PM2.5 LC TOR',
#                'EC1 PM2.5 LC',
#                'EC2 PM2.5 LC',
#                'EC3 PM2.5 LC',
#                'Iron PM2.5 LC',
#                'Lead PM2.5 LC',
#                'Light Absorption Coeffiecient',
#                'Magnesium PM2.5 LC',
#                'Manganese PM2.5 LC',
#                'Nickel PM2.5 LC',
#                'Nitrite PM2.5 LC',
#                'OC PM2.5 LC TOR',
#                'OC1 PM2.5 LC',
#                'OC2 PM2.5 LC',
#                'OC3 PM2.5 LC',
#                'OC4 PM2.5 LC',
#                'OP PM2.5 LC TOR',
#                'Organic Carbon Mass PM2.5 LC',
#                'Ozone',
#                'PM10 - LC',
#                'PM10-2.5 - Local Conditions',
#                'PM2.5 - Local Conditions',
#                'Phosphorus PM2.5 LC',
#                'Potassium PM2.5 LC',
#                'Rubidium PM2.5 LC',
#                'Selenium PM2.5 LC',
#                'Silicon PM2.5 LC',
#                'Sodium PM2.5 LC',
#                'Soil PM2.5 LC',
#                'Strontium PM2.5 LC',
#                'Sulfate PM2.5 LC',
#                'Sulfur PM2.5 LC',
#                'Titanium PM2.5 LC',
#                'Total Nitrate PM2.5 LC',
#                'Vanadium PM2.5 LC',
#                'Zinc PM2.5 LC',
#                'Zirconium PM2.5 LC'},
#               'Southwest Minnesota Regional Airport': {'Ozone',
#                'PM10 Total 0-10um STP',
#                'PM2.5 - Local Conditions'},
#               'Virginia City Hall': {'Arsenic (TSP) LC',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Chromium (TSP) LC',
#                'Lead (TSP) LC',
#                'Manganese (TSP) LC',
#                'Nickel (TSP) LC',
#                'Nitric oxide (NO)',
#                'Nitrogen dioxide (NO2)',
#                'Oxides of nitrogen (NOx)',
#                'PM10 Total 0-10um STP',
#                'PM2.5 - Local Conditions',
#                'SO2 max 5-min avg',
#                'Selenium (TSP) LC',
#                'Sulfur dioxide',
#                'Suspended particulate (TSP)'},
#               'Saint Paul Park Refinery 436': {'SO2 max 5-min avg',
#                'Sulfur dioxide',
#                'Total reduced sulfur'},
#               'Ben Franklin School': {'Ozone', 'PM2.5 - Local Conditions'},
#               'Grand Portage Band': {'PM2.5 - Local Conditions'},
#               'Federal Cartridge': {'Arsenic (TSP) LC',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Chromium (TSP) LC',
#                'Lead (TSP) LC',
#                'Manganese (TSP) LC',
#                'Nickel (TSP) LC',
#                'Selenium (TSP) LC',
#                'Suspended particulate (TSP)',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant',
#                'Wind Speed - Scalar'},
#               'Near Road I-35': {'Carbon monoxide',
#                'Nitric oxide (NO)',
#                'Nitrogen dioxide (NO2)',
#                'Oxides of nitrogen (NOx)',
#                'PM2.5 - Local Conditions',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant',
#                'Wind Speed - Scalar'},
#               'Red Rock Road': {'PM10 Total 0-10um STP'},
#               'Harding High School': {'Ambient Max Temperature',
#                'Ambient Min Temperature',
#                'Arsenic (TSP) LC',
#                'Average Ambient Pressure',
#                'Average Ambient Temperature',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Chromium (TSP) LC',
#                'Elapsed Sample Time',
#                'Lead (TSP) LC',
#                'Manganese (TSP) LC',
#                'Nickel (TSP) LC',
#                'PM2.5 - Local Conditions',
#                'Sample Flow Rate- CV',
#                'Sample Max Baro Pressure',
#                'Sample Min Baro Pressure',
#                'Sample Volume',
#                'Selenium (TSP) LC',
#                'Suspended particulate (TSP)'},
#               'Oneota Street': {'PM10 Total 0-10um STP'},
#               'Near Road I-35/I-94': {'Arsenic (TSP) LC',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Carbon monoxide',
#                'Chromium (TSP) LC',
#                'Lead (TSP) LC',
#                'Manganese (TSP) LC',
#                'Nickel (TSP) LC',
#                'Nitric oxide (NO)',
#                'Nitrogen dioxide (NO2)',
#                'Oxides of nitrogen (NOx)',
#                'Ozone',
#                'PM2.5 - Local Conditions',
#                'Selenium (TSP) LC',
#                'Suspended particulate (TSP)',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant',
#                'Wind Speed - Scalar'},
#               'Talahi School': {'Ozone', 'PM2.5 - Local Conditions'},
#               'Mille Lacs Band': {'Ozone'},
#               'Flint Hills Refinery 420': {'Arsenic (TSP) LC',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Carbon monoxide',
#                'Chromium (TSP) LC',
#                'Lead (TSP) LC',
#                'Manganese (TSP) LC',
#                'Nickel (TSP) LC',
#                'Nitric oxide (NO)',
#                'Nitrogen dioxide (NO2)',
#                'Oxides of nitrogen (NOx)',
#                'SO2 max 5-min avg',
#                'Selenium (TSP) LC',
#                'Sulfur dioxide',
#                'Suspended particulate (TSP)',
#                'Total reduced sulfur',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant',
#                'Wind Speed - Scalar'},
#               'St. Louis Park City Hall': {'Ambient Max Temperature',
#                'Ambient Min Temperature',
#                'Average Ambient Pressure',
#                'Average Ambient Temperature',
#                'Elapsed Sample Time',
#                'PM2.5 - Local Conditions',
#                'Sample Flow Rate- CV',
#                'Sample Max Baro Pressure',
#                'Sample Min Baro Pressure',
#                'Sample Volume'},
#               'St. Paul Brass': {'Arsenic (TSP) LC',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Chromium (TSP) LC',
#                'Lead (TSP) LC',
#                'Manganese (TSP) LC',
#                'Nickel (TSP) LC',
#                'Selenium (TSP) LC',
#                'Suspended particulate (TSP)'},
#               'Humboldt Avenue': {'Arsenic (TSP) LC',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Chromium (TSP) LC',
#                'Lead (TSP) LC',
#                'Manganese (TSP) LC',
#                'Nickel (TSP) LC',
#                'Selenium (TSP) LC',
#                'Suspended particulate (TSP)'},
#               'Red Lake Nation': {'PM2.5 - Local Conditions'},
#               'Leech Lake Nation:': {'PM2.5 - Local Conditions'},
#               'Bottineau / Marshall Terrace': {'Arsenic (TSP) LC',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Chromium (TSP) LC',
#                'Lead (TSP) LC',
#                'Manganese (TSP) LC',
#                'Nickel (TSP) LC',
#                'PM10 Total 0-10um STP',
#                'Selenium (TSP) LC',
#                'Suspended particulate (TSP)'},
#               'West Side': {'Arsenic (TSP) LC',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Chromium (TSP) LC',
#                'Lead (TSP) LC',
#                'Manganese (TSP) LC',
#                'Nickel (TSP) LC',
#                'Selenium (TSP) LC',
#                'Suspended particulate (TSP)'},
#               'Voyageurs NP #2': {'Acceptable PM2.5 AQI & Speciation Mass',
#                'Aluminum PM2.5 LC',
#                'Ammonium Nitrate PM2.5 LC',
#                'Ammonium Sulfate PM2.5 LC',
#                'Arsenic PM2.5 LC',
#                'Bromine PM2.5 LC',
#                'Calcium PM2.5 LC',
#                'Chloride PM2.5 LC',
#                'Chlorine PM2.5 LC',
#                'Chromium PM2.5 LC',
#                'Copper PM2.5 LC',
#                'EC PM2.5 LC TOR',
#                'EC1 PM2.5 LC',
#                'EC2 PM2.5 LC',
#                'EC3 PM2.5 LC',
#                'Iron PM2.5 LC',
#                'Lead PM2.5 LC',
#                'Light Absorption Coeffiecient',
#                'Magnesium PM2.5 LC',
#                'Manganese PM2.5 LC',
#                'Nickel PM2.5 LC',
#                'Nitrite PM2.5 LC',
#                'OC PM2.5 LC TOR',
#                'OC1 PM2.5 LC',
#                'OC2 PM2.5 LC',
#                'OC3 PM2.5 LC',
#                'OC4 PM2.5 LC',
#                'OP PM2.5 LC TOR',
#                'Organic Carbon Mass PM2.5 LC',
#                'Outdoor Temperature',
#                'Ozone',
#                'PM10 - LC',
#                'PM10-2.5 - Local Conditions',
#                'Phosphorus PM2.5 LC',
#                'Potassium PM2.5 LC',
#                'Relative Humidity ',
#                'Rubidium PM2.5 LC',
#                'Selenium PM2.5 LC',
#                'Silicon PM2.5 LC',
#                'Sodium PM2.5 LC',
#                'Soil PM2.5 LC',
#                'Std Dev Hz Wind Direction',
#                'Strontium PM2.5 LC',
#                'Sulfate PM2.5 LC',
#                'Sulfur PM2.5 LC',
#                'Titanium PM2.5 LC',
#                'Total Nitrate PM2.5 LC',
#                'Vanadium PM2.5 LC',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant',
#                'Wind Speed - Scalar',
#                'Zinc PM2.5 LC',
#                'Zirconium PM2.5 LC'},
#               'Folwell School': {'Arsenic (TSP) LC',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Chromium (TSP) LC',
#                'Lead (TSP) LC',
#                'Manganese (TSP) LC',
#                'Nickel (TSP) LC',
#                'Selenium (TSP) LC',
#                'Suspended particulate (TSP)'},
#               'St. Croix Watershed Research Station': {'Ozone'}},
#              'Ohio': {'Painesville': {'Ozone',
#                'PM2.5 - Local Conditions',
#                'SO2 max 5-min avg',
#                'Sulfur dioxide'},
#               'Cleveland Near Road': {'Carbon monoxide',
#                'Nitric oxide (NO)',
#                'Nitrogen dioxide (NO2)',
#                'Oxides of nitrogen (NOx)',
#                'PM2.5 - Local Conditions'},
#               'BW Site 12 Shaw': {'Beryllium (TSP) STP'},
#               'Conneaut': {'Indoor Temperature', 'Ozone'},
#               'Harvard Yards': {'Acceptable PM2.5 AQI & Speciation Mass',
#                'Aluminum PM2.5 LC',
#                'Ammonium Ion PM2.5 LC',
#                'Antimony PM2.5 LC',
#                'Arsenic PM2.5 LC',
#                'Average Ambient Pressure',
#                'Average Ambient Pressure for URG3000N',
#                'Average Ambient Temperature',
#                'Average Ambient Temperature for URG3000N',
#                'Barium PM2.5 LC',
#                'Bromine PM2.5 LC',
#                'Cadmium PM2.5 LC',
#                'Calcium PM2.5 LC',
#                'Cerium PM2.5 LC',
#                'Cesium PM2.5 LC',
#                'Chloride PM2.5 LC',
#                'Chlorine PM2.5 LC',
#                'Chromium PM2.5 LC',
#                'Cobalt PM2.5 LC',
#                'Copper PM2.5 LC',
#                'EC CSN_Rev Unadjusted PM2.5 LC TOR',
#                'EC CSN_Rev Unadjusted PM2.5 LC TOT',
#                'EC PM2.5 LC TOR',
#                'EC PM2.5 LC TOT',
#                'EC1 CSN_Rev Unadjusted PM2.5 LC',
#                'EC1 PM2.5 LC',
#                'EC2 CSN_Rev Unadjusted PM2.5 LC',
#                'EC2 PM2.5 LC',
#                'EC3 CSN_Rev Unadjusted PM2.5 LC',
#                'EC3 PM2.5 LC',
#                'Indium PM2.5 LC',
#                'Iron PM2.5 LC',
#                'Lead PM2.5 LC',
#                'Light Absorption Coeffiecient',
#                'Magnesium PM2.5 LC',
#                'Manganese PM2.5 LC',
#                'Nickel PM2.5 LC',
#                'OC CSN_Rev Unadjusted PM2.5 LC TOR',
#                'OC CSN_Rev Unadjusted PM2.5 LC TOT',
#                'OC PM2.5 LC TOR',
#                'OC PM2.5 LC TOT',
#                'OC1 CSN_Rev Unadjusted PM2.5 LC',
#                'OC1 PM2.5 LC',
#                'OC2 CSN_Rev Unadjusted PM2.5 LC',
#                'OC2 PM2.5 LC',
#                'OC3 CSN_Rev Unadjusted PM2.5 LC',
#                'OC3 PM2.5 LC',
#                'OC4 CSN_Rev Unadjusted PM2.5 LC',
#                'OC4 PM2.5 LC',
#                'OP CSN_Rev Unadjusted PM2.5 LC TOR',
#                'OP CSN_Rev Unadjusted PM2.5 LC TOT',
#                'OP PM2.5 LC TOR',
#                'OP PM2.5 LC TOT',
#                'PM10 Total 0-10um STP',
#                'PM2.5 - Local Conditions',
#                'Phosphorus PM2.5 LC',
#                'Potassium Ion PM2.5 LC',
#                'Potassium PM2.5 LC',
#                'Reconstructed Mass PM2.5 LC',
#                'Rubidium PM2.5 LC',
#                'SO2 max 5-min avg',
#                'Sample Flow Rate CV - Nylon Filter',
#                'Sample Flow Rate CV - Quartz Filter',
#                'Sample Flow Rate CV - Teflon Filter',
#                'Sample Volume - Nylon Filter',
#                'Sample Volume - Quartz Filter',
#                'Sample Volume - Teflon Filter',
#                'Selenium PM2.5 LC',
#                'Silicon PM2.5 LC',
#                'Silver PM2.5 LC',
#                'Sodium Ion Pm2.5 LC',
#                'Sodium PM2.5 LC',
#                'Soil PM2.5 LC',
#                'Strontium PM2.5 LC',
#                'Sulfate PM2.5 LC',
#                'Sulfur PM2.5 LC',
#                'Sulfur dioxide',
#                'Tin PM2.5 LC',
#                'Titanium PM2.5 LC',
#                'Total Nitrate PM2.5 LC',
#                'Vanadium PM2.5 LC',
#                'Zinc PM2.5 LC',
#                'Zirconium PM2.5 LC'},
#               'Cincinnati Near Road': {'Black Carbon PM2.5 at 880 nm',
#                'Carbon monoxide',
#                'Nitric oxide (NO)',
#                'Nitrogen dioxide (NO2)',
#                'Oxides of nitrogen (NOx)',
#                'PM2.5 - Local Conditions'},
#               'GT Craig NCore PAMS': {'Aluminum PM2.5 LC',
#                'Ammonium Ion PM2.5 LC',
#                'Antimony PM2.5 LC',
#                'Arsenic PM2.5 LC',
#                'Average Ambient Pressure',
#                'Average Ambient Pressure for URG3000N',
#                'Average Ambient Temperature',
#                'Average Ambient Temperature for URG3000N',
#                'Barium PM2.5 LC',
#                'Barometric pressure',
#                'Bromine PM2.5 LC',
#                'Cadmium PM2.5 LC',
#                'Calcium PM2.5 LC',
#                'Carbon monoxide',
#                'Cerium PM2.5 LC',
#                'Cesium PM2.5 LC',
#                'Chloride PM2.5 LC',
#                'Chlorine PM2.5 LC',
#                'Chromium PM2.5 LC',
#                'Cobalt PM2.5 LC',
#                'Copper PM2.5 LC',
#                'EC CSN_Rev Unadjusted PM2.5 LC TOR',
#                'EC CSN_Rev Unadjusted PM2.5 LC TOT',
#                'EC PM2.5 LC TOR',
#                'EC PM2.5 LC TOT',
#                'EC1 CSN_Rev Unadjusted PM2.5 LC',
#                'EC1 PM2.5 LC',
#                'EC2 CSN_Rev Unadjusted PM2.5 LC',
#                'EC2 PM2.5 LC',
#                'EC3 CSN_Rev Unadjusted PM2.5 LC',
#                'EC3 PM2.5 LC',
#                'Indium PM2.5 LC',
#                'Iron PM2.5 LC',
#                'Lead PM2.5 LC',
#                'Light Absorption Coeffiecient',
#                'Magnesium PM2.5 LC',
#                'Manganese PM2.5 LC',
#                'Nickel PM2.5 LC',
#                'Nitric oxide (NO)',
#                'Nitrogen dioxide (NO2)',
#                'OC CSN_Rev Unadjusted PM2.5 LC TOR',
#                'OC CSN_Rev Unadjusted PM2.5 LC TOT',
#                'OC PM2.5 LC TOR',
#                'OC PM2.5 LC TOT',
#                'OC1 CSN_Rev Unadjusted PM2.5 LC',
#                'OC1 PM2.5 LC',
#                'OC2 CSN_Rev Unadjusted PM2.5 LC',
#                'OC2 PM2.5 LC',
#                'OC3 CSN_Rev Unadjusted PM2.5 LC',
#                'OC3 PM2.5 LC',
#                'OC4 CSN_Rev Unadjusted PM2.5 LC',
#                'OC4 PM2.5 LC',
#                'OP CSN_Rev Unadjusted PM2.5 LC TOR',
#                'OP CSN_Rev Unadjusted PM2.5 LC TOT',
#                'OP PM2.5 LC TOR',
#                'OP PM2.5 LC TOT',
#                'Outdoor Temperature',
#                'Ozone',
#                'PM1 - Local Conditions',
#                'PM10 Total 0-10um STP',
#                'PM10-2.5 - Local Conditions',
#                'PM2.5 - Local Conditions',
#                'Phosphorus PM2.5 LC',
#                'Potassium Ion PM2.5 LC',
#                'Potassium PM2.5 LC',
#                'Rain/melt precipitation',
#                'Reactive oxides of nitrogen (NOy)',
#                'Reconstructed Mass PM2.5 LC',
#                'Relative Humidity ',
#                'Rubidium PM2.5 LC',
#                'SO2 max 5-min avg',
#                'Sample Flow Rate CV - Nylon Filter',
#                'Sample Flow Rate CV - Quartz Filter',
#                'Sample Flow Rate CV - Teflon Filter',
#                'Sample Volume - Nylon Filter',
#                'Sample Volume - Quartz Filter',
#                'Sample Volume - Teflon Filter',
#                'Selenium PM2.5 LC',
#                'Silicon PM2.5 LC',
#                'Silver PM2.5 LC',
#                'Sodium Ion Pm2.5 LC',
#                'Sodium PM2.5 LC',
#                'Soil PM2.5 LC',
#                'Solar radiation',
#                'Strontium PM2.5 LC',
#                'Sulfate PM2.5 LC',
#                'Sulfur PM2.5 LC',
#                'Sulfur dioxide',
#                'Tin PM2.5 LC',
#                'Titanium PM2.5 LC',
#                'Total Nitrate PM2.5 LC',
#                'Ultraviolet radiation',
#                'Vanadium PM2.5 LC',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant',
#                'Zinc PM2.5 LC',
#                'Zirconium PM2.5 LC'},
#               'Marietta WTP': {'Ozone'},
#               'Republic Community': {'Arsenic (TSP) LC',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Chromium (TSP) LC',
#                'Lead (TSP) LC',
#                'Lead (TSP) LC Non-FRM/FEM',
#                'Manganese (TSP) LC',
#                'Nickel (TSP) LC',
#                'Zinc (TSP) LC'},
#               'New Albany': {'Acceptable PM2.5 AQI & Speciation Mass',
#                'Indoor Temperature',
#                'Ozone'},
#               'Delaware': {'Indoor Temperature', 'Ozone'},
#               'Springfield Fire St1': {'PM2.5 - Local Conditions'},
#               'Sycamore': {'Ozone', 'PM2.5 - Local Conditions'},
#               'Reynoldsburg': {'Indoor Temperature', 'Ozone'},
#               'Brewster': {'Ozone'},
#               'Gallia Pike South': {'PM10 Total 0-10um STP',
#                'SO2 max 5-min avg',
#                'Sulfur dioxide'},
#               'Eastwood': {'Ozone'},
#               'Springfield Well Fd': {'Ozone'},
#               'BPG': {'PM2.5 - Local Conditions'},
#               'Ridge': {'Outdoor Temperature',
#                'SO2 max 5-min avg',
#                'Sulfur dioxide',
#                'Wind Direction - Scalar',
#                'Wind Speed - Scalar'},
#               'Cleveland Fire St13': {'PM10 Total 0-10um STP',
#                'PM2.5 - Local Conditions'},
#               'Girard WWTP': {'PM10 Total 0-10um STP'},
#               'Globe': {'SO2 max 5-min avg', 'Sulfur dioxide'},
#               'BW Site 15 Peters': {'Beryllium (TSP) STP'},
#               'Guiding Hand': {'Indoor Temperature',
#                'SO2 max 5-min avg',
#                'Sulfur dioxide'},
#               'District 6': {'Ozone', 'PM2.5 - Local Conditions'},
#               'Eastlake': {'Ozone'},
#               'Steubenville': {'1,1,2,2-Tetrachloroethane',
#                '1,1,2-Trichloro-1,2,2-trifluoroethane',
#                '1,1,2-Trichloroethane',
#                '1,1-Dichloroethane',
#                '1,1-Dichloroethylene',
#                '1,2,4-Trichlorobenzene',
#                '1,2,4-Trimethylbenzene',
#                '1,2-Dichlorobenzene',
#                '1,2-Dichloropropane',
#                '1,3,5-Trimethylbenzene',
#                '1,3-Butadiene',
#                '1,3-Dichlorobenzene',
#                '1,3-Dichloropropene(total)',
#                '1,4-Dichlorobenzene',
#                '1,4-Dioxane',
#                '2,2,4-Trimethylpentane',
#                '2-Propanol',
#                '3-Chloropropene',
#                'Acetone',
#                'Acrolein - Unverified',
#                'Acrylonitrile',
#                'Aluminum PM2.5 LC',
#                'Ammonium Ion PM2.5 LC',
#                'Antimony PM2.5 LC',
#                'Arsenic PM2.5 LC',
#                'Average Ambient Pressure',
#                'Average Ambient Pressure for URG3000N',
#                'Average Ambient Temperature',
#                'Average Ambient Temperature for URG3000N',
#                'Barium PM2.5 LC',
#                'Benzene',
#                'Benzyl chloride',
#                'Bromine PM2.5 LC',
#                'Bromodichloromethane',
#                'Bromoform',
#                'Bromomethane',
#                'Cadmium PM2.5 LC',
#                'Calcium PM2.5 LC',
#                'Carbon disulfide',
#                'Carbon tetrachloride',
#                'Cerium PM2.5 LC',
#                'Cesium PM2.5 LC',
#                'Chloride PM2.5 LC',
#                'Chlorine PM2.5 LC',
#                'Chlorobenzene',
#                'Chloroethane',
#                'Chloroform',
#                'Chloromethane',
#                'Chromium PM2.5 LC',
#                'Cobalt PM2.5 LC',
#                'Copper PM2.5 LC',
#                'Cyclohexane',
#                'Dibromochloromethane',
#                'Dichlorodifluoromethane',
#                'Dichloromethane',
#                'EC CSN_Rev Unadjusted PM2.5 LC TOR',
#                'EC CSN_Rev Unadjusted PM2.5 LC TOT',
#                'EC PM2.5 LC TOR',
#                'EC PM2.5 LC TOT',
#                'EC1 CSN_Rev Unadjusted PM2.5 LC',
#                'EC1 PM2.5 LC',
#                'EC2 CSN_Rev Unadjusted PM2.5 LC',
#                'EC2 PM2.5 LC',
#                'EC3 CSN_Rev Unadjusted PM2.5 LC',
#                'EC3 PM2.5 LC',
#                'Ethyl acetate',
#                'Ethyl alcohol',
#                'Ethylbenzene',
#                'Ethylene dibromide',
#                'Ethylene dichloride',
#                'Freon 114',
#                'Furan, tetrahydro-',
#                'Hexachlorobutadiene',
#                'Indium PM2.5 LC',
#                'Indoor Temperature',
#                'Iron PM2.5 LC',
#                'Isopropylbenzene',
#                'Lead PM2.5 LC',
#                'Light Absorption Coeffiecient',
#                'Magnesium PM2.5 LC',
#                'Manganese PM2.5 LC',
#                'Methyl Butyl Ketone',
#                'Methyl chloroform',
#                'Methyl ethyl ketone',
#                'Methyl isobutyl ketone',
#                'Methyl methacrylate',
#                'Methyl tert-butyl ether',
#                'Naphthalene',
#                'Nickel PM2.5 LC',
#                'OC CSN_Rev Unadjusted PM2.5 LC TOR',
#                'OC CSN_Rev Unadjusted PM2.5 LC TOT',
#                'OC PM2.5 LC TOR',
#                'OC PM2.5 LC TOT',
#                'OC1 CSN_Rev Unadjusted PM2.5 LC',
#                'OC1 PM2.5 LC',
#                'OC2 CSN_Rev Unadjusted PM2.5 LC',
#                'OC2 PM2.5 LC',
#                'OC3 CSN_Rev Unadjusted PM2.5 LC',
#                'OC3 PM2.5 LC',
#                'OC4 CSN_Rev Unadjusted PM2.5 LC',
#                'OC4 PM2.5 LC',
#                'OP CSN_Rev Unadjusted PM2.5 LC TOR',
#                'OP CSN_Rev Unadjusted PM2.5 LC TOT',
#                'OP PM2.5 LC TOR',
#                'OP PM2.5 LC TOT',
#                'Ozone',
#                'PM10 Total 0-10um STP',
#                'PM2.5 - Local Conditions',
#                'Phosphorus PM2.5 LC',
#                'Potassium Ion PM2.5 LC',
#                'Potassium PM2.5 LC',
#                'Propylene',
#                'Reconstructed Mass PM2.5 LC',
#                'Rubidium PM2.5 LC',
#                'SO2 max 5-min avg',
#                'Sample Flow Rate CV - Nylon Filter',
#                'Sample Flow Rate CV - Quartz Filter',
#                'Sample Flow Rate CV - Teflon Filter',
#                'Sample Volume - Nylon Filter',
#                'Sample Volume - Quartz Filter',
#                'Sample Volume - Teflon Filter',
#                'Selenium PM2.5 LC',
#                'Silicon PM2.5 LC',
#                'Silver PM2.5 LC',
#                'Sodium Ion Pm2.5 LC',
#                'Sodium PM2.5 LC',
#                'Soil PM2.5 LC',
#                'Strontium PM2.5 LC',
#                'Styrene',
#                'Sulfate PM2.5 LC',
#                'Sulfur PM2.5 LC',
#                'Sulfur dioxide',
#                'Tetrachloroethylene',
#                'Tin PM2.5 LC',
#                'Titanium PM2.5 LC',
#                'Toluene',
#                'Total Nitrate PM2.5 LC',
#                'Trichloroethylene',
#                'Trichlorofluoromethane',
#                'Vanadium PM2.5 LC',
#                'Vinyl acetate',
#                'Vinyl bromide',
#                'Vinyl chloride',
#                'Zinc PM2.5 LC',
#                'Zirconium PM2.5 LC',
#                'cis-1,2-Dichloroethene',
#                'm/p Xylene',
#                'n-Butane',
#                'n-Heptane',
#                'n-Hexane',
#                'o-Xylene',
#                'p-Ethyltoluene',
#                'trans-1,2-Dichloroethylene',
#                'trans-1,3-Dichloropropene'},
#               'Quaker City': {'Acceptable PM2.5 AQI & Speciation Mass',
#                'Aluminum PM2.5 LC',
#                'Ammonium Nitrate PM2.5 LC',
#                'Ammonium Sulfate PM2.5 LC',
#                'Arsenic PM2.5 LC',
#                'Bromine PM2.5 LC',
#                'Calcium PM2.5 LC',
#                'Chloride PM2.5 LC',
#                'Chlorine PM2.5 LC',
#                'Chromium PM2.5 LC',
#                'Copper PM2.5 LC',
#                'EC PM2.5 LC TOR',
#                'EC1 PM2.5 LC',
#                'EC2 PM2.5 LC',
#                'EC3 PM2.5 LC',
#                'Iron PM2.5 LC',
#                'Lead PM2.5 LC',
#                'Light Absorption Coeffiecient',
#                'Magnesium PM2.5 LC',
#                'Manganese PM2.5 LC',
#                'Nickel PM2.5 LC',
#                'Nitrite PM2.5 LC',
#                'OC PM2.5 LC TOR',
#                'OC1 PM2.5 LC',
#                'OC2 PM2.5 LC',
#                'OC3 PM2.5 LC',
#                'OC4 PM2.5 LC',
#                'OP PM2.5 LC TOR',
#                'Organic Carbon Mass PM2.5 LC',
#                'Ozone',
#                'PM10 - LC',
#                'PM10-2.5 - Local Conditions',
#                'Phosphorus PM2.5 LC',
#                'Potassium PM2.5 LC',
#                'Rubidium PM2.5 LC',
#                'Selenium PM2.5 LC',
#                'Silicon PM2.5 LC',
#                'Sodium PM2.5 LC',
#                'Soil PM2.5 LC',
#                'Strontium PM2.5 LC',
#                'Sulfate PM2.5 LC',
#                'Sulfur PM2.5 LC',
#                'Titanium PM2.5 LC',
#                'Total Nitrate PM2.5 LC',
#                'Vanadium PM2.5 LC',
#                'Zinc PM2.5 LC',
#                'Zirconium PM2.5 LC'},
#               'BW Site 19 Paule': {'Beryllium (TSP) STP'},
#               'Canton': {'PM2.5 - Local Conditions'},
#               'BW Site 11 Dehring': {'Beryllium (TSP) STP'},
#               'Wilgus': {'Ozone'},
#               'BW Site 18 Goetz': {'Beryllium (TSP) STP'},
#               'London': {'Indoor Temperature', 'Ozone'},
#               'Bowling Green': {'Ozone'},
#               'Jackson Pike WWTP': {'Arsenic (TSP) LC',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Chromium (TSP) LC',
#                'Lead (TSP) LC',
#                'Lead (TSP) LC Non-FRM/FEM',
#                'Manganese (TSP) LC',
#                'Nickel (TSP) LC',
#                'PM10 Total 0-10um STP',
#                'PM2.5 - Local Conditions',
#                'Zinc (TSP) LC'},
#               'Yankee': {'1,1,2,2-Tetrachloroethane',
#                '1,1,2-Trichloro-1,2,2-trifluoroethane',
#                '1,1,2-Trichloroethane',
#                '1,1-Dichloroethane',
#                '1,1-Dichloroethylene',
#                '1,2,4-Trichlorobenzene',
#                '1,2,4-Trimethylbenzene',
#                '1,2-Dichlorobenzene',
#                '1,2-Dichloropropane',
#                '1,3,5-Trimethylbenzene',
#                '1,3-Butadiene',
#                '1,3-Dichlorobenzene',
#                '1,4-Dichlorobenzene',
#                '1,4-Dioxane',
#                '2,2,4-Trimethylpentane',
#                '2-Propanol',
#                '3-Chloropropene',
#                'Acetone',
#                'Acrolein - Unverified',
#                'Acrylonitrile',
#                'Benzene',
#                'Benzyl chloride',
#                'Bromodichloromethane',
#                'Bromoform',
#                'Bromomethane',
#                'Carbon disulfide',
#                'Carbon tetrachloride',
#                'Chlorobenzene',
#                'Chloroethane',
#                'Chloroform',
#                'Chloromethane',
#                'Cyclohexane',
#                'Dibromochloromethane',
#                'Dichlorodifluoromethane',
#                'Dichloromethane',
#                'Ethyl acetate',
#                'Ethyl alcohol',
#                'Ethylbenzene',
#                'Ethylene dibromide',
#                'Ethylene dichloride',
#                'Freon 114',
#                'Furan, tetrahydro-',
#                'Hexachlorobutadiene',
#                'Isopropylbenzene',
#                'Methyl Butyl Ketone',
#                'Methyl chloroform',
#                'Methyl ethyl ketone',
#                'Methyl isobutyl ketone',
#                'Methyl methacrylate',
#                'Methyl tert-butyl ether',
#                'Naphthalene',
#                'PM10 Total 0-10um STP',
#                'PM2.5 - Local Conditions',
#                'Propylene',
#                'SO2 max 5-min avg',
#                'Styrene',
#                'Sulfur dioxide',
#                'Tetrachloroethylene',
#                'Toluene',
#                'Trichloroethylene',
#                'Trichlorofluoromethane',
#                'Vinyl acetate',
#                'Vinyl bromide',
#                'Vinyl chloride',
#                'cis-1,2-Dichloroethene',
#                'cis-1,3-Dichloropropene',
#                'm/p Xylene',
#                'n-Butane',
#                'n-Heptane',
#                'n-Hexane',
#                'o-Xylene',
#                'p-Ethyltoluene',
#                'trans-1,2-Dichloroethylene',
#                'trans-1,3-Dichloropropene'},
#               'Delta': {'Arsenic (TSP) LC',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Chromium (TSP) LC',
#                'Lead (TSP) LC',
#                'Lead (TSP) LC Non-FRM/FEM',
#                'Manganese (TSP) LC',
#                'Nickel (TSP) LC',
#                'Zinc (TSP) LC'},
#               'Galleria': {'Carbon monoxide'},
#               'Notre Dame': {'Ozone'},
#               'Laird Eng Bldg': {'PM10 Total 0-10um STP',
#                'PM2.5 - Local Conditions'},
#               'North HS': {'Ozone'},
#               'Port Authority': {'Arsenic (TSP) LC',
#                'Beryllium (TSP) LC',
#                'Cadmium (TSP) LC',
#                'Chromium (TSP) LC',
#                'Lead (TSP) LC',
#                'Lead (TSP) LC Non-FRM/FEM',
#                'Manganese (TSP) LC',
#                'Mercury (TSP) LC',
#                'Nickel (TSP) LC',
#                'Zinc (TSP) LC'},
#               'Centerburg WWTP': {'Indoor Temperature', 'Ozone'},
#               'Southerly WWTP': {'Acceptable PM2.5 AQI & Speciation Mass',
#                'Aluminum PM2.5 LC',
#                'Ammonium Ion PM2.5 LC',
#                'Antimony PM2.5 LC',
#                'Arsenic PM2.5 LC',
#                'Average Ambient Pressure',
#                'Average Ambient Pressure for URG3000N',
#                'Average Ambient Temperature',
#                'Average Ambient Temperature for URG3000N',
#                'Barium PM2.5 LC',
#                'Bromine PM2.5 LC',
#                'Cadmium PM2.5 LC',
#                'Calcium PM2.5 LC',
#                'Cerium PM2.5 LC',
#                'Cesium PM2.5 LC',
#                'Chloride PM2.5 LC',
#                'Chlorine PM2.5 LC',
#                'Chromium PM2.5 LC',
#                'Cobalt PM2.5 LC',
#                'Copper PM2.5 LC',
#                'EC CSN_Rev Unadjusted PM2.5 LC TOR',
#                'EC CSN_Rev Unadjusted PM2.5 LC TOT',
#                'EC PM2.5 LC TOR',
# ...
#                'Zinc PM2.5 LC',
#                'Zirconium PM2.5 LC',
#                'alpha.-Pinene',
#                'beta.-Pinene',
#                'cis-2-Butene',
#                'cis-2-Pentene',
#                'm-Diethylbenzene',
#                'm-Ethyltoluene',
#                'm/p Xylene',
#                'n-Butane',
#                'n-Decane',
#                'n-Heptane',
#                'n-Hexane',
#                'n-Nonane',
#                'n-Octane',
#                'n-Pentane',
#                'n-Propylbenzene',
#                'n-Undecane',
#                'o-Ethyltoluene',
#                'o-Xylene',
#                'p-Diethylbenzene',
#                'p-Ethyltoluene',
#                'trans-2-Butene',
#                'trans-2-Pentene'},
#               'MILLER STATE PARK': {'Acceptable PM2.5 AQI & Speciation Mass',
#                'Aluminum PM2.5 LC',
#                'Ammonium Nitrate PM2.5 LC',
#                'Ammonium Sulfate PM2.5 LC',
#                'Arsenic PM2.5 LC',
#                'Barometric pressure',
#                'Bromine PM2.5 LC',
#                'Calcium PM2.5 LC',
#                'Carbon monoxide',
#                'Chloride PM2.5 LC',
#                'Chlorine PM2.5 LC',
#                'Chromium PM2.5 LC',
#                'Copper PM2.5 LC',
#                'EC PM2.5 LC TOR',
#                'EC1 PM2.5 LC',
#                'EC2 PM2.5 LC',
#                'EC3 PM2.5 LC',
#                'Iron PM2.5 LC',
#                'Lead PM2.5 LC',
#                'Light Absorption Coeffiecient',
#                'Magnesium PM2.5 LC',
#                'Manganese PM2.5 LC',
#                'NOy - NO',
#                'Nickel PM2.5 LC',
#                'Nitric oxide (NO)',
#                'Nitrite PM2.5 LC',
#                'OC PM2.5 LC TOR',
#                'OC1 PM2.5 LC',
#                'OC2 PM2.5 LC',
#                'OC3 PM2.5 LC',
#                'OC4 PM2.5 LC',
#                'OP PM2.5 LC TOR',
#                'Organic Carbon Mass PM2.5 LC',
#                'Outdoor Temperature',
#                'Ozone',
#                'PM10 - LC',
#                'PM10 Total 0-10um STP',
#                'PM10-2.5 - Local Conditions',
#                'PM2.5 - Local Conditions',
#                'Phosphorus PM2.5 LC',
#                'Potassium PM2.5 LC',
#                'Rain/melt precipitation',
#                'Reactive oxides of nitrogen (NOy)',
#                'Relative Humidity ',
#                'Rubidium PM2.5 LC',
#                'Selenium PM2.5 LC',
#                'Silicon PM2.5 LC',
#                'Sodium PM2.5 LC',
#                'Soil PM2.5 LC',
#                'Std Dev Hz Wind Direction',
#                'Strontium PM2.5 LC',
#                'Sulfate PM2.5 LC',
#                'Sulfur PM2.5 LC',
#                'Sulfur dioxide',
#                'Titanium PM2.5 LC',
#                'Total Nitrate PM2.5 LC',
#                'Vanadium PM2.5 LC',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant',
#                'Zinc PM2.5 LC',
#                'Zirconium PM2.5 LC'},
#               'Woodstock': {'Ozone'},
#               'HAZEN DRIVE': {'Outdoor Temperature',
#                'Ozone',
#                'Std Dev Hz Wind Direction',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant'},
#               'SEACOAST SCIENCE CENTER': {'Outdoor Temperature',
#                'Ozone',
#                'Std Dev Hz Wind Direction',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant'},
#               nan: set(),
#               'LEBANON AIRPORT ROAD': {'Outdoor Temperature',
#                'Ozone',
#                'PM10 - LC',
#                'PM10-2.5 - Local Conditions',
#                'PM2.5 - Local Conditions',
#                'Std Dev Hz Wind Direction',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant'},
#               'GILSON ROAD': {'Outdoor Temperature',
#                'Ozone',
#                'Std Dev Hz Wind Direction',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant'},
#               'CAMP DODGE, GREENS GRANT': {'Acceptable PM2.5 AQI & Speciation Mass',
#                'Aluminum PM2.5 LC',
#                'Ammonium Nitrate PM2.5 LC',
#                'Ammonium Sulfate PM2.5 LC',
#                'Arsenic PM2.5 LC',
#                'Bromine PM2.5 LC',
#                'Calcium PM2.5 LC',
#                'Chloride PM2.5 LC',
#                'Chlorine PM2.5 LC',
#                'Chromium PM2.5 LC',
#                'Copper PM2.5 LC',
#                'EC PM2.5 LC TOR',
#                'EC1 PM2.5 LC',
#                'EC2 PM2.5 LC',
#                'EC3 PM2.5 LC',
#                'Iron PM2.5 LC',
#                'Lead PM2.5 LC',
#                'Light Absorption Coeffiecient',
#                'Magnesium PM2.5 LC',
#                'Manganese PM2.5 LC',
#                'Nickel PM2.5 LC',
#                'Nitrite PM2.5 LC',
#                'OC PM2.5 LC TOR',
#                'OC1 PM2.5 LC',
#                'OC2 PM2.5 LC',
#                'OC3 PM2.5 LC',
#                'OC4 PM2.5 LC',
#                'OP PM2.5 LC TOR',
#                'Organic Carbon Mass PM2.5 LC',
#                'Outdoor Temperature',
#                'Ozone',
#                'PM10 - LC',
#                'PM10-2.5 - Local Conditions',
#                'Phosphorus PM2.5 LC',
#                'Potassium PM2.5 LC',
#                'Rubidium PM2.5 LC',
#                'Selenium PM2.5 LC',
#                'Silicon PM2.5 LC',
#                'Sodium PM2.5 LC',
#                'Soil PM2.5 LC',
#                'Strontium PM2.5 LC',
#                'Sulfate PM2.5 LC',
#                'Sulfur PM2.5 LC',
#                'Titanium PM2.5 LC',
#                'Total Nitrate PM2.5 LC',
#                'Vanadium PM2.5 LC',
#                'Zinc PM2.5 LC',
#                'Zirconium PM2.5 LC'},
#               'PORTSMOUTH - PEIRCE ISLAND': {'Outdoor Temperature',
#                'Ozone',
#                'PM10 - LC',
#                'PM10 Total 0-10um STP',
#                'PM10-2.5 - Local Conditions',
#                'PM2.5 - Local Conditions',
#                'Std Dev Hz Wind Direction',
#                'Sulfur dioxide',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant'}},
#              'Connecticut': {'Roosevelt School-Bridgeport': {'Outdoor Temperature',
#                'PM10 - LC',
#                'PM10 Total 0-10um STP',
#                'PM10-2.5 - Local Conditions',
#                'PM2.5 - Local Conditions',
#                'Sulfur dioxide'},
#               'Fort Griswold Park': {'Outdoor Temperature',
#                'Ozone',
#                'PM10 - LC',
#                'PM10-2.5 - Local Conditions',
#                'PM2.5 - Local Conditions'},
#               'CVH': {'Barometric pressure',
#                'Outdoor Temperature',
#                'Ozone',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant'},
#               'Meadow and Bank Streets': {'Outdoor Temperature',
#                'PM10 - LC',
#                'PM10-2.5 - Local Conditions',
#                'PM2.5 - Local Conditions',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant'},
#               'Huntley Place-Hartford': {'Barometric pressure',
#                'Black Carbon PM2.5 at 880 nm',
#                'Black carbon PM2.5 STP',
#                'Carbon monoxide',
#                'Nitrogen dioxide (NO2)',
#                'Outdoor Temperature',
#                'PM10 - LC',
#                'PM10 Total 0-10um STP',
#                'PM10-2.5 - Local Conditions',
#                'PM2.5 - Local Conditions',
#                'UV Carbon PM2.5 STP',
#                'UV Carbon PM2.5 at 370 nm',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant'},
#               'Greenwich Point Park': {'Outdoor Temperature',
#                'Ozone',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant'},
#               'Mohawk Mt-Cornwall': {'Acceptable PM2.5 AQI & Speciation Mass',
#                'Aluminum PM2.5 LC',
#                'Ammonium Nitrate PM2.5 LC',
#                'Ammonium Sulfate PM2.5 LC',
#                'Arsenic PM2.5 LC',
#                'Barometric pressure',
#                'Black Carbon PM2.5 at 880 nm',
#                'Black carbon PM2.5 STP',
#                'Bromine PM2.5 LC',
#                'Calcium PM2.5 LC',
#                'Carbon monoxide',
#                'Chloride PM2.5 LC',
#                'Chlorine PM2.5 LC',
#                'Chromium PM2.5 LC',
#                'Copper PM2.5 LC',
#                'Dew Point',
#                'EC PM2.5 LC TOR',
#                'EC1 PM2.5 LC',
#                'EC2 PM2.5 LC',
#                'EC3 PM2.5 LC',
#                'Iron PM2.5 LC',
#                'Lead PM2.5 LC',
#                'Light Absorption Coeffiecient',
#                'Magnesium PM2.5 LC',
#                'Manganese PM2.5 LC',
#                'Nickel PM2.5 LC',
#                'Nitric oxide (NO)',
#                'Nitrite PM2.5 LC',
#                'OC PM2.5 LC TOR',
#                'OC1 PM2.5 LC',
#                'OC2 PM2.5 LC',
#                'OC3 PM2.5 LC',
#                'OC4 PM2.5 LC',
#                'OP PM2.5 LC TOR',
#                'Organic Carbon Mass PM2.5 LC',
#                'Outdoor Temperature',
#                'Ozone',
#                'PM10 - LC',
#                'PM10-2.5 - Local Conditions',
#                'PM2.5 - Local Conditions',
#                'Phosphorus PM2.5 LC',
#                'Potassium PM2.5 LC',
#                'Reactive oxides of nitrogen (NOy)',
#                'Relative Humidity ',
#                'Rubidium PM2.5 LC',
#                'Selenium PM2.5 LC',
#                'Silicon PM2.5 LC',
#                'Sodium PM2.5 LC',
#                'Soil PM2.5 LC',
#                'Solar radiation',
#                'Strontium PM2.5 LC',
#                'Sulfate PM2.5 LC',
#                'Sulfur PM2.5 LC',
#                'Sulfur dioxide',
#                'Titanium PM2.5 LC',
#                'Total Nitrate PM2.5 LC',
#                'UV Carbon PM2.5 STP',
#                'UV Carbon PM2.5 at 370 nm',
#                'Vanadium PM2.5 LC',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant',
#                'Zinc PM2.5 LC',
#                'Zirconium PM2.5 LC'},
#               'Shenipsit State Forest': {'Outdoor Temperature',
#                'Ozone',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant'},
#               'Western Conn State Univ': {'Barometric pressure',
#                'Black Carbon PM2.5 at 880 nm',
#                'Black carbon PM2.5 STP',
#                'Outdoor Temperature',
#                'Ozone',
#                'PM10 - LC',
#                'PM10-2.5 - Local Conditions',
#                'PM2.5 - Local Conditions',
#                'UV Carbon PM2.5 STP',
#                'UV Carbon PM2.5 at 370 nm',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant'},
#               'McAuliffe Park': {'Barometric pressure',
#                'Black Carbon PM2.5 at 880 nm',
#                'Black carbon PM2.5 STP',
#                'Dew Point',
#                'Nitrogen dioxide (NO2)',
#                'Outdoor Temperature',
#                'Ozone',
#                'PM10 - LC',
#                'PM10 Total 0-10um STP',
#                'PM10-2.5 - Local Conditions',
#                'PM2.5 - Local Conditions',
#                'Relative Humidity ',
#                'UV Carbon PM2.5 STP',
#                'UV Carbon PM2.5 at 370 nm',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant'},
#               'Hammonasset State Park': {'Outdoor Temperature',
#                'Ozone',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant'},
#               'USGS Lighthouse': {'Outdoor Temperature', 'Ozone'},
#               'Abington': {'Ozone'},
#               'Sherwood Island Connector': {'Nitrogen dioxide (NO2)',
#                'Outdoor Temperature',
#                'Ozone',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant'},
#               'Criscuolo Park-New Haven': {'Aluminum PM2.5 LC',
#                'Ammonium Ion PM2.5 LC',
#                'Antimony PM2.5 LC',
#                'Arsenic PM2.5 LC',
#                'Average Ambient Pressure',
#                'Average Ambient Pressure for URG3000N',
#                'Average Ambient Temperature',
#                'Average Ambient Temperature for URG3000N',
#                'Barium PM2.5 LC',
#                'Barometric pressure',
#                'Black Carbon PM2.5 at 880 nm',
#                'Black carbon PM2.5 STP',
#                'Bromine PM2.5 LC',
#                'Cadmium PM2.5 LC',
#                'Calcium PM2.5 LC',
#                'Carbon monoxide',
#                'Cerium PM2.5 LC',
#                'Cesium PM2.5 LC',
#                'Chloride PM2.5 LC',
#                'Chlorine PM2.5 LC',
#                'Chromium PM2.5 LC',
#                'Cobalt PM2.5 LC',
#                'Copper PM2.5 LC',
#                'Dew Point',
#                'EC CSN_Rev Unadjusted PM2.5 LC TOR',
#                'EC CSN_Rev Unadjusted PM2.5 LC TOT',
#                'EC PM2.5 LC TOR',
#                'EC PM2.5 LC TOT',
#                'EC1 CSN_Rev Unadjusted PM2.5 LC',
#                'EC1 PM2.5 LC',
#                'EC2 CSN_Rev Unadjusted PM2.5 LC',
#                'EC2 PM2.5 LC',
#                'EC3 CSN_Rev Unadjusted PM2.5 LC',
#                'EC3 PM2.5 LC',
#                'Indium PM2.5 LC',
#                'Iron PM2.5 LC',
#                'Lead PM2.5 LC',
#                'Light Absorption Coeffiecient',
#                'Magnesium PM2.5 LC',
#                'Manganese PM2.5 LC',
#                'Nickel PM2.5 LC',
#                'Nitric oxide (NO)',
#                'Nitrogen dioxide (NO2)',
#                'OC CSN_Rev Unadjusted PM2.5 LC TOR',
#                'OC CSN_Rev Unadjusted PM2.5 LC TOT',
#                'OC PM2.5 LC TOR',
#                'OC PM2.5 LC TOT',
#                'OC1 CSN_Rev Unadjusted PM2.5 LC',
#                'OC1 PM2.5 LC',
#                'OC2 CSN_Rev Unadjusted PM2.5 LC',
#                'OC2 PM2.5 LC',
#                'OC3 CSN_Rev Unadjusted PM2.5 LC',
#                'OC3 PM2.5 LC',
#                'OC4 CSN_Rev Unadjusted PM2.5 LC',
#                'OC4 PM2.5 LC',
#                'OP CSN_Rev Unadjusted PM2.5 LC TOR',
#                'OP CSN_Rev Unadjusted PM2.5 LC TOT',
#                'OP PM2.5 LC TOR',
#                'OP PM2.5 LC TOT',
#                'Outdoor Temperature',
#                'Ozone',
#                'PM10 - LC',
#                'PM10 Total 0-10um STP',
#                'PM10-2.5 - Local Conditions',
#                'PM2.5 - Local Conditions',
#                'Phosphorus PM2.5 LC',
#                'Potassium Ion PM2.5 LC',
#                'Potassium PM2.5 LC',
#                'Reactive oxides of nitrogen (NOy)',
#                'Reconstructed Mass PM2.5 LC',
#                'Relative Humidity ',
#                'Rubidium PM2.5 LC',
#                'Sample Flow Rate CV - Nylon Filter',
#                'Sample Flow Rate CV - Quartz Filter',
#                'Sample Flow Rate CV - Teflon Filter',
#                'Sample Volume - Nylon Filter',
#                'Sample Volume - Quartz Filter',
#                'Sample Volume - Teflon Filter',
#                'Selenium PM2.5 LC',
#                'Silicon PM2.5 LC',
#                'Silver PM2.5 LC',
#                'Sodium Ion Pm2.5 LC',
#                'Sodium PM2.5 LC',
#                'Soil PM2.5 LC',
#                'Solar radiation',
#                'Strontium PM2.5 LC',
#                'Sulfate PM2.5 LC',
#                'Sulfur PM2.5 LC',
#                'Sulfur dioxide',
#                'Tin PM2.5 LC',
#                'Titanium PM2.5 LC',
#                'Total Nitrate PM2.5 LC',
#                'UV Carbon PM2.5 STP',
#                'UV Carbon PM2.5 at 370 nm',
#                'Vanadium PM2.5 LC',
#                'Wind Direction - Resultant',
#                'Wind Speed - Resultant',
#                'Zinc PM2.5 LC',
#                'Zirconium PM2.5 LC'}}})

# %%
tested["Utah"]
# Out:
# {'STATION NEAR INTERSECTION OF WHITEROCK CANYON RD & QURAY CANAL': {'Barometric pressure',
#   'Net radiation',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'Peak Wind Gust',
#   'Relative Humidity ',
#   'Solar radiation',
#   'Temperature Difference',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar'},
#  'Hurricane': {'Barometric pressure',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM2.5 - Local Conditions',
#   'Relative Humidity ',
#   'Solar radiation',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar'},
#  'Hawthorne': {'1,2,3-Trimethylbenzene',
#   '1,2,4-Trimethylbenzene',
#   '1,3,5-Trimethylbenzene',
#   '1,3-Butadiene',
#   '1-Butene',
#   '1-Hexene',
#   '1-Pentene',
#   '2,2,4-Trimethylpentane',
#   '2,2-Dimethylbutane',
#   '2,3,4-Trimethylpentane',
#   '2,3-Dimethylbutane',
#   '2,3-Dimethylpentane',
#   '2,4-Dimethylpentane',
#   '2-Methyl-1-pentene',
#   '2-Methylheptane',
#   '2-Methylhexane',
#   '2-Methylpentane',
#   '3-Methylheptane',
#   '3-Methylhexane',
#   '3-Methylpentane',
#   'Acetaldehyde',
#   'Acetone',
#   'Acetylene',
#   'Aluminum PM2.5 LC',
#   'Ambient Max Temperature',
#   'Ambient Min Temperature',
#   'Ammonium Ion PM2.5 LC',
#   'Antimony PM2.5 LC',
#   'Arsenic PM2.5 LC',
#   'Average Ambient Pressure',
#   'Average Ambient Pressure for URG3000N',
#   'Average Ambient Temperature',
#   'Average Ambient Temperature for URG3000N',
#   'Barium PM2.5 LC',
#   'Barometric pressure',
#   'Benzaldehyde',
#   'Benzene',
#   'Bromine PM2.5 LC',
#   'Butyraldehyde',
#   'Cadmium PM2.5 LC',
#   'Calcium PM2.5 LC',
#   'Carbon monoxide',
#   'Cerium PM2.5 LC',
#   'Cesium PM2.5 LC',
#   'Chloride PM2.5 LC',
#   'Chlorine PM2.5 LC',
#   'Chromium PM2.5 LC',
#   'Cobalt PM2.5 LC',
#   'Copper PM2.5 LC',
#   'Crotonaldehyde',
#   'Cyclohexane',
#   'Cyclopentane',
#   'EC CSN_Rev Unadjusted PM2.5 LC TOR',
#   'EC CSN_Rev Unadjusted PM2.5 LC TOT',
#   'EC PM2.5 LC TOR',
#   'EC PM2.5 LC TOT',
#   'EC1 CSN_Rev Unadjusted PM2.5 LC',
#   'EC1 PM2.5 LC',
#   'EC2 CSN_Rev Unadjusted PM2.5 LC',
#   'EC2 PM2.5 LC',
#   'EC3 CSN_Rev Unadjusted PM2.5 LC',
#   'EC3 PM2.5 LC',
#   'Elapsed Sample Time',
#   'Ethane',
#   'Ethylbenzene',
#   'Ethylene',
#   'Formaldehyde',
#   'Hexanaldehyde',
#   'Indium PM2.5 LC',
#   'Iron PM2.5 LC',
#   'Isobutane',
#   'Isopentane',
#   'Isoprene',
#   'Isopropylbenzene',
#   'Lead PM2.5 LC',
#   'Light Absorption Coeffiecient',
#   'Magnesium PM2.5 LC',
#   'Manganese PM2.5 LC',
#   'Methyl ethyl ketone',
#   'Methylcyclohexane',
#   'Methylcyclopentane',
#   'Mixing Height',
#   'NOy - NO',
#   'Nickel PM2.5 LC',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'OC CSN_Rev Unadjusted PM2.5 LC TOR',
#   'OC CSN_Rev Unadjusted PM2.5 LC TOT',
#   'OC PM2.5 LC TOR',
#   'OC PM2.5 LC TOT',
#   'OC1 CSN_Rev Unadjusted PM2.5 LC',
#   'OC1 PM2.5 LC',
#   'OC2 CSN_Rev Unadjusted PM2.5 LC',
#   'OC2 PM2.5 LC',
#   'OC3 CSN_Rev Unadjusted PM2.5 LC',
#   'OC3 PM2.5 LC',
#   'OC4 CSN_Rev Unadjusted PM2.5 LC',
#   'OC4 PM2.5 LC',
#   'OP CSN_Rev Unadjusted PM2.5 LC TOR',
#   'OP CSN_Rev Unadjusted PM2.5 LC TOT',
#   'OP PM2.5 LC TOR',
#   'OP PM2.5 LC TOT',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM10 - LC',
#   'PM10 Total 0-10um STP',
#   'PM10-2.5 - Local Conditions',
#   'PM2.5 - Local Conditions',
#   'Phosphorus PM2.5 LC',
#   'Potassium Ion PM2.5 LC',
#   'Potassium PM2.5 LC',
#   'Propane',
#   'Propionaldehyde',
#   'Propylene',
#   'Reactive oxides of nitrogen (NOy)',
#   'Reconstructed Mass PM2.5 LC',
#   'Relative Humidity ',
#   'Rubidium PM2.5 LC',
#   'Sample Flow Rate CV - Nylon Filter',
#   'Sample Flow Rate CV - Quartz Filter',
#   'Sample Flow Rate CV - Teflon Filter',
#   'Sample Flow Rate- CV',
#   'Sample Max Baro Pressure',
#   'Sample Min Baro Pressure',
#   'Sample Volume',
#   'Sample Volume - Nylon Filter',
#   'Sample Volume - Quartz Filter',
#   'Sample Volume - Teflon Filter',
#   'Selenium PM2.5 LC',
#   'Silicon PM2.5 LC',
#   'Silver PM2.5 LC',
#   'Sodium Ion Pm2.5 LC',
#   'Sodium PM2.5 LC',
#   'Soil PM2.5 LC',
#   'Solar radiation',
#   'Strontium PM2.5 LC',
#   'Styrene',
#   'Sulfate PM2.5 LC',
#   'Sulfur PM2.5 LC',
#   'Sulfur dioxide',
#   'Tin PM2.5 LC',
#   'Titanium PM2.5 LC',
#   'Toluene',
#   'Total NMOC (non-methane organic compound)',
#   'Total Nitrate PM2.5 LC',
#   'Valeraldehyde',
#   'Vanadium PM2.5 LC',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar',
#   'Zinc PM2.5 LC',
#   'Zirconium PM2.5 LC',
#   'alpha.-Pinene',
#   'beta.-Pinene',
#   'cis-2-Butene',
#   'cis-2-Pentene',
#   'm-Diethylbenzene',
#   'm-Ethyltoluene',
#   'm/p Xylene',
#   'n-Butane',
#   'n-Decane',
#   'n-Dodecane',
#   'n-Heptane',
#   'n-Hexane',
#   'n-Nonane',
#   'n-Octane',
#   'n-Pentane',
#   'n-Propylbenzene',
#   'n-Undecane',
#   'o-Ethyltoluene',
#   'o-Xylene',
#   'p-Diethylbenzene',
#   'p-Ethyltoluene',
#   'trans-2-Butene',
#   'trans-2-Pentene'},
#  'Canyonlands NP': {'Acceptable PM2.5 AQI & Speciation Mass',
#   'Aluminum PM2.5 LC',
#   'Ammonium Nitrate PM2.5 LC',
#   'Ammonium Sulfate PM2.5 LC',
#   'Arsenic PM2.5 LC',
#   'Bromine PM2.5 LC',
#   'Calcium PM2.5 LC',
#   'Chloride PM2.5 LC',
#   'Chlorine PM2.5 LC',
#   'Chromium PM2.5 LC',
#   'Copper PM2.5 LC',
#   'EC PM2.5 LC TOR',
#   'EC1 PM2.5 LC',
#   'EC2 PM2.5 LC',
#   'EC3 PM2.5 LC',
#   'Iron PM2.5 LC',
#   'Lead PM2.5 LC',
#   'Light Absorption Coeffiecient',
#   'Magnesium PM2.5 LC',
#   'Manganese PM2.5 LC',
#   'Nickel PM2.5 LC',
#   'Nitrite PM2.5 LC',
#   'OC PM2.5 LC TOR',
#   'OC1 PM2.5 LC',
#   'OC2 PM2.5 LC',
#   'OC3 PM2.5 LC',
#   'OC4 PM2.5 LC',
#   'OP PM2.5 LC TOR',
#   'Organic Carbon Mass PM2.5 LC',
#   'Outdoor Temperature',
#   'Ozone',
#   'PM10 - LC',
#   'PM10-2.5 - Local Conditions',
#   'Phosphorus PM2.5 LC',
#   'Potassium PM2.5 LC',
#   'Relative Humidity ',
#   'Rubidium PM2.5 LC',
#   'Selenium PM2.5 LC',
#   'Silicon PM2.5 LC',
#   'Sodium PM2.5 LC',
#   'Soil PM2.5 LC',
#   'Std Dev Hz Wind Direction',
#   'Strontium PM2.5 LC',
#   'Sulfate PM2.5 LC',
#   'Sulfur PM2.5 LC',
#   'Titanium PM2.5 LC',
#   'Total Nitrate PM2.5 LC',
#   'Vanadium PM2.5 LC',
#   'Wind Direction - Resultant',
#   'Wind Speed - Resultant',
#   'Wind Speed - Scalar',
#   'Zinc PM2.5 LC',
#   'Zirconium PM2.5 LC'},
#  'Badger Isaland': {'Outdoor Temperature',
#   'Relative Humidity ',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar'},
#  'Copper View': {'Ambient Max Temperature',
#   'Ambient Min Temperature',
#   'Average Ambient Pressure',
#   'Average Ambient Temperature',
#   'Barometric pressure',
#   'Carbon monoxide',
#   'Elapsed Sample Time',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM2.5 - Local Conditions',
#   'Relative Humidity ',
#   'Sample Flow Rate- CV',
#   'Sample Max Baro Pressure',
#   'Sample Min Baro Pressure',
#   'Sample Volume',
#   'Solar radiation',
#   'Sulfur dioxide',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar'},
#  'Vernal #4': {'Ambient Max Temperature',
#   'Ambient Min Temperature',
#   'Average Ambient Pressure',
#   'Average Ambient Temperature',
#   'Barometric pressure',
#   'Elapsed Sample Time',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM2.5 - Local Conditions',
#   'Relative Humidity ',
#   'Sample Flow Rate- CV',
#   'Sample Max Baro Pressure',
#   'Sample Min Baro Pressure',
#   'Sample Volume',
#   'Solar radiation',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar'},
#  'Bryce Canyon NP': {'Acceptable PM2.5 AQI & Speciation Mass',
#   'Aluminum PM2.5 LC',
#   'Ammonium Nitrate PM2.5 LC',
#   'Ammonium Sulfate PM2.5 LC',
#   'Arsenic PM2.5 LC',
#   'Bromine PM2.5 LC',
#   'Calcium PM2.5 LC',
#   'Chloride PM2.5 LC',
#   'Chlorine PM2.5 LC',
#   'Chromium PM2.5 LC',
#   'Copper PM2.5 LC',
#   'EC PM2.5 LC TOR',
#   'EC1 PM2.5 LC',
#   'EC2 PM2.5 LC',
#   'EC3 PM2.5 LC',
#   'Iron PM2.5 LC',
#   'Lead PM2.5 LC',
#   'Light Absorption Coeffiecient',
#   'Magnesium PM2.5 LC',
#   'Manganese PM2.5 LC',
#   'Nickel PM2.5 LC',
#   'Nitrite PM2.5 LC',
#   'OC PM2.5 LC TOR',
#   'OC1 PM2.5 LC',
#   'OC2 PM2.5 LC',
#   'OC3 PM2.5 LC',
#   'OC4 PM2.5 LC',
#   'OP PM2.5 LC TOR',
#   'Organic Carbon Mass PM2.5 LC',
#   'PM10 - LC',
#   'PM10-2.5 - Local Conditions',
#   'Phosphorus PM2.5 LC',
#   'Potassium PM2.5 LC',
#   'Rubidium PM2.5 LC',
#   'Selenium PM2.5 LC',
#   'Silicon PM2.5 LC',
#   'Sodium PM2.5 LC',
#   'Soil PM2.5 LC',
#   'Strontium PM2.5 LC',
#   'Sulfate PM2.5 LC',
#   'Sulfur PM2.5 LC',
#   'Titanium PM2.5 LC',
#   'Total Nitrate PM2.5 LC',
#   'Vanadium PM2.5 LC',
#   'Zinc PM2.5 LC',
#   'Zirconium PM2.5 LC'},
#  'Near Road': {'Ambient Max Temperature',
#   'Ambient Min Temperature',
#   'Average Ambient Pressure',
#   'Average Ambient Temperature',
#   'Barometric pressure',
#   'Carbon monoxide',
#   'Elapsed Sample Time',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM2.5 - Local Conditions',
#   'Relative Humidity ',
#   'Sample Flow Rate- CV',
#   'Sample Max Baro Pressure',
#   'Sample Min Baro Pressure',
#   'Sample Volume',
#   'Solar radiation',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar'},
#  'Brigham City #3': {'Ambient Max Temperature',
#   'Ambient Min Temperature',
#   'Average Ambient Pressure',
#   'Average Ambient Temperature',
#   'Barometric pressure',
#   'Elapsed Sample Time',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM10 - LC',
#   'PM10 Total 0-10um STP',
#   'PM2.5 - Local Conditions',
#   'Relative Humidity ',
#   'Sample Flow Rate- CV',
#   'Sample Max Baro Pressure',
#   'Sample Min Baro Pressure',
#   'Sample Volume',
#   'Solar radiation',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar'},
#  'Dinosaur NM - West Entrance Housing': {'Outdoor Temperature',
#   'Ozone',
#   'Rain/melt precipitation',
#   'Solar radiation',
#   'Std Dev Hz Wind Direction',
#   'Wind Direction - Resultant',
#   'Wind Speed - Resultant',
#   'Wind Speed - Scalar'},
#  'Roosevelt': {'Ambient Max Temperature',
#   'Ambient Min Temperature',
#   'Average Ambient Pressure',
#   'Average Ambient Temperature',
#   'Barometric pressure',
#   'Elapsed Sample Time',
#   'Mixing Height',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM10 - LC',
#   'PM10 Total 0-10um STP',
#   'PM2.5 - Local Conditions',
#   'Relative Humidity ',
#   'Sample Flow Rate- CV',
#   'Sample Max Baro Pressure',
#   'Sample Min Baro Pressure',
#   'Sample Volume',
#   'Solar radiation',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar'},
#  'Herriman #3': {'Barometric pressure',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM10 Total 0-10um STP',
#   'PM2.5 - Local Conditions',
#   'Relative Humidity ',
#   'Solar radiation',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar'},
#  'Heber': {'Ambient Max Temperature',
#   'Ambient Min Temperature',
#   'Average Ambient Pressure',
#   'Average Ambient Temperature',
#   'Barometric pressure',
#   'Elapsed Sample Time',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM2.5 - Local Conditions',
#   'Relative Humidity ',
#   'Sample Flow Rate- CV',
#   'Sample Max Baro Pressure',
#   'Sample Min Baro Pressure',
#   'Sample Volume',
#   'Solar radiation',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar'},
#  'Utah Technical Center': {'1,2,3-Trimethylbenzene',
#   '1,2,4-Trimethylbenzene',
#   '1,3,5-Trimethylbenzene',
#   '1,3-Butadiene',
#   '1-Butene',
#   '1-Hexene',
#   '1-Pentene',
#   '2,2,4-Trimethylpentane',
#   '2,2-Dimethylbutane',
#   '2,3,4-Trimethylpentane',
#   '2,3-Dimethylbutane',
#   '2,3-Dimethylpentane',
#   '2,4-Dimethylpentane',
#   '2-Methylheptane',
#   '2-Methylhexane',
#   '2-Methylpentane',
#   '3-Methylheptane',
#   '3-Methylhexane',
#   '3-Methylpentane',
#   'Acetylene',
#   'Ambient Max Temperature',
#   'Ambient Min Temperature',
#   'Average Ambient Pressure',
#   'Average Ambient Temperature',
#   'Barometric pressure',
#   'Benzene',
#   'Carbon monoxide',
#   'Cyclohexane',
#   'Cyclopentane',
#   'Elapsed Sample Time',
#   'Ethane',
#   'Ethylbenzene',
#   'Ethylene',
#   'Isobutane',
#   'Isopentane',
#   'Isoprene',
#   'Isopropylbenzene',
#   'Methylcyclohexane',
#   'Methylcyclopentane',
#   'Mixing Height',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM10 - LC',
#   'PM10 Total 0-10um STP',
#   'PM2.5 - Local Conditions',
#   'Propane',
#   'Propylene',
#   'Relative Humidity ',
#   'Sample Flow Rate- CV',
#   'Sample Max Baro Pressure',
#   'Sample Min Baro Pressure',
#   'Sample Volume',
#   'Solar radiation',
#   'Styrene',
#   'Sulfur dioxide',
#   'Toluene',
#   'Total NMOC (non-methane organic compound)',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar',
#   'cis-2-Butene',
#   'cis-2-Pentene',
#   'm-Diethylbenzene',
#   'm-Ethyltoluene',
#   'm/p Xylene',
#   'n-Butane',
#   'n-Decane',
#   'n-Dodecane',
#   'n-Heptane',
#   'n-Hexane',
#   'n-Nonane',
#   'n-Octane',
#   'n-Pentane',
#   'n-Propylbenzene',
#   'n-Undecane',
#   'o-Ethyltoluene',
#   'o-Xylene',
#   'p-Diethylbenzene',
#   'p-Ethyltoluene',
#   'trans-2-Butene',
#   'trans-2-Pentene'},
#  nan: set(),
#  'Zion Canyon': {'Acceptable PM2.5 AQI & Speciation Mass',
#   'Aluminum PM2.5 LC',
#   'Ammonium Nitrate PM2.5 LC',
#   'Ammonium Sulfate PM2.5 LC',
#   'Arsenic PM2.5 LC',
#   'Bromine PM2.5 LC',
#   'Calcium PM2.5 LC',
#   'Chloride PM2.5 LC',
#   'Chlorine PM2.5 LC',
#   'Chromium PM2.5 LC',
#   'Copper PM2.5 LC',
#   'EC PM2.5 LC TOR',
#   'EC1 PM2.5 LC',
#   'EC2 PM2.5 LC',
#   'EC3 PM2.5 LC',
#   'Iron PM2.5 LC',
#   'Lead PM2.5 LC',
#   'Light Absorption Coeffiecient',
#   'Magnesium PM2.5 LC',
#   'Manganese PM2.5 LC',
#   'Nickel PM2.5 LC',
#   'Nitrite PM2.5 LC',
#   'OC PM2.5 LC TOR',
#   'OC1 PM2.5 LC',
#   'OC2 PM2.5 LC',
#   'OC3 PM2.5 LC',
#   'OC4 PM2.5 LC',
#   'OP PM2.5 LC TOR',
#   'Organic Carbon Mass PM2.5 LC',
#   'Outdoor Temperature',
#   'Ozone',
#   'PM10 - LC',
#   'PM10-2.5 - Local Conditions',
#   'Phosphorus PM2.5 LC',
#   'Potassium PM2.5 LC',
#   'Rubidium PM2.5 LC',
#   'Selenium PM2.5 LC',
#   'Silicon PM2.5 LC',
#   'Sodium PM2.5 LC',
#   'Soil PM2.5 LC',
#   'Std Dev Hz Wind Direction',
#   'Strontium PM2.5 LC',
#   'Sulfate PM2.5 LC',
#   'Sulfur PM2.5 LC',
#   'Titanium PM2.5 LC',
#   'Total Nitrate PM2.5 LC',
#   'Vanadium PM2.5 LC',
#   'Wind Direction - Resultant',
#   'Wind Speed - Resultant',
#   'Wind Speed - Scalar',
#   'Zinc PM2.5 LC',
#   'Zirconium PM2.5 LC'},
#  'Lindon': {'Aluminum PM2.5 LC',
#   'Ambient Max Temperature',
#   'Ambient Min Temperature',
#   'Ammonium Ion PM2.5 LC',
#   'Antimony PM2.5 LC',
#   'Arsenic PM2.5 LC',
#   'Average Ambient Pressure',
#   'Average Ambient Pressure for URG3000N',
#   'Average Ambient Temperature',
#   'Average Ambient Temperature for URG3000N',
#   'Barium PM2.5 LC',
#   'Barometric pressure',
#   'Black Carbon PM2.5 at 880 nm',
#   'Bromine PM2.5 LC',
#   'Cadmium PM2.5 LC',
#   'Calcium PM2.5 LC',
#   'Carbon monoxide',
#   'Cerium PM2.5 LC',
#   'Cesium PM2.5 LC',
#   'Chloride PM2.5 LC',
#   'Chlorine PM2.5 LC',
#   'Chromium PM2.5 LC',
#   'Cobalt PM2.5 LC',
#   'Copper PM2.5 LC',
#   'EC CSN_Rev Unadjusted PM2.5 LC TOR',
#   'EC CSN_Rev Unadjusted PM2.5 LC TOT',
#   'EC PM2.5 LC TOR',
#   'EC PM2.5 LC TOT',
#   'EC1 CSN_Rev Unadjusted PM2.5 LC',
#   'EC1 PM2.5 LC',
#   'EC2 CSN_Rev Unadjusted PM2.5 LC',
#   'EC2 PM2.5 LC',
#   'EC3 CSN_Rev Unadjusted PM2.5 LC',
#   'EC3 PM2.5 LC',
#   'Elapsed Sample Time',
#   'Indium PM2.5 LC',
#   'Iron PM2.5 LC',
#   'Lead PM2.5 LC',
#   'Light Absorption Coeffiecient',
#   'Magnesium PM2.5 LC',
#   'Manganese PM2.5 LC',
#   'Nickel PM2.5 LC',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'OC CSN_Rev Unadjusted PM2.5 LC TOR',
#   'OC CSN_Rev Unadjusted PM2.5 LC TOT',
#   'OC PM2.5 LC TOR',
#   'OC PM2.5 LC TOT',
#   'OC1 CSN_Rev Unadjusted PM2.5 LC',
#   'OC1 PM2.5 LC',
#   'OC2 CSN_Rev Unadjusted PM2.5 LC',
#   'OC2 PM2.5 LC',
#   'OC3 CSN_Rev Unadjusted PM2.5 LC',
#   'OC3 PM2.5 LC',
#   'OC4 CSN_Rev Unadjusted PM2.5 LC',
#   'OC4 PM2.5 LC',
#   'OP CSN_Rev Unadjusted PM2.5 LC TOR',
#   'OP CSN_Rev Unadjusted PM2.5 LC TOT',
#   'OP PM2.5 LC TOR',
#   'OP PM2.5 LC TOT',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM10 Total 0-10um STP',
#   'PM2.5 - Local Conditions',
#   'Phosphorus PM2.5 LC',
#   'Potassium Ion PM2.5 LC',
#   'Potassium PM2.5 LC',
#   'Reconstructed Mass PM2.5 LC',
#   'Relative Humidity ',
#   'Rubidium PM2.5 LC',
#   'Sample Flow Rate CV - Nylon Filter',
#   'Sample Flow Rate CV - Quartz Filter',
#   'Sample Flow Rate CV - Teflon Filter',
#   'Sample Flow Rate- CV',
#   'Sample Max Baro Pressure',
#   'Sample Min Baro Pressure',
#   'Sample Volume',
#   'Sample Volume - Nylon Filter',
#   'Sample Volume - Quartz Filter',
#   'Sample Volume - Teflon Filter',
#   'Selenium PM2.5 LC',
#   'Silicon PM2.5 LC',
#   'Silver PM2.5 LC',
#   'Sodium Ion Pm2.5 LC',
#   'Sodium PM2.5 LC',
#   'Soil PM2.5 LC',
#   'Solar radiation',
#   'Strontium PM2.5 LC',
#   'Sulfate PM2.5 LC',
#   'Sulfur PM2.5 LC',
#   'Tin PM2.5 LC',
#   'Titanium PM2.5 LC',
#   'Total Nitrate PM2.5 LC',
#   'Vanadium PM2.5 LC',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar',
#   'Zinc PM2.5 LC',
#   'Zirconium PM2.5 LC'},
#  'Erda': {'1,2,3-Trimethylbenzene',
#   '1,2,4-Trimethylbenzene',
#   '1,3,5-Trimethylbenzene',
#   '1,3-Butadiene',
#   '1-Butene',
#   '1-Hexene',
#   '1-Pentene',
#   '2,2,4-Trimethylpentane',
#   '2,2-Dimethylbutane',
#   '2,3,4-Trimethylpentane',
#   '2,3-Dimethylbutane',
#   '2,3-Dimethylpentane',
#   '2,4-Dimethylpentane',
#   '2-Methylheptane',
#   '2-Methylhexane',
#   '2-Methylpentane',
#   '3-Methylheptane',
#   '3-Methylhexane',
#   '3-Methylpentane',
#   'Acetylene',
#   'Ambient Max Temperature',
#   'Ambient Min Temperature',
#   'Average Ambient Pressure',
#   'Average Ambient Temperature',
#   'Barometric pressure',
#   'Benzene',
#   'Cyclohexane',
#   'Cyclopentane',
#   'Elapsed Sample Time',
#   'Ethane',
#   'Ethylbenzene',
#   'Ethylene',
#   'Isobutane',
#   'Isopentane',
#   'Isoprene',
#   'Isopropylbenzene',
#   'Methylcyclohexane',
#   'Methylcyclopentane',
#   'NOy - NO',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM2.5 - Local Conditions',
#   'Propane',
#   'Propylene',
#   'Reactive oxides of nitrogen (NOy)',
#   'Relative Humidity ',
#   'Sample Flow Rate- CV',
#   'Sample Max Baro Pressure',
#   'Sample Min Baro Pressure',
#   'Sample Volume',
#   'Solar radiation',
#   'Styrene',
#   'Toluene',
#   'Total NMOC (non-methane organic compound)',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar',
#   'cis-2-Butene',
#   'cis-2-Pentene',
#   'm-Diethylbenzene',
#   'm-Ethyltoluene',
#   'm/p Xylene',
#   'n-Butane',
#   'n-Decane',
#   'n-Dodecane',
#   'n-Heptane',
#   'n-Hexane',
#   'n-Nonane',
#   'n-Octane',
#   'n-Pentane',
#   'n-Propylbenzene',
#   'n-Undecane',
#   'o-Ethyltoluene',
#   'o-Xylene',
#   'p-Diethylbenzene',
#   'p-Ethyltoluene',
#   'trans-2-Butene',
#   'trans-2-Pentene'},
#  'Inland Port': {'Barometric pressure',
#   'Black Carbon PM2.5 at 880 nm',
#   'Mixing Height',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM10 - LC',
#   'PM10 Total 0-10um STP',
#   'PM2.5 - Local Conditions',
#   'Relative Humidity ',
#   'Solar radiation',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar'},
#  'Smithfield': {'Aluminum PM2.5 LC',
#   'Ambient Max Temperature',
#   'Ambient Min Temperature',
#   'Ammonium Ion PM2.5 LC',
#   'Antimony PM2.5 LC',
#   'Arsenic PM2.5 LC',
#   'Average Ambient Pressure',
#   'Average Ambient Pressure for URG3000N',
#   'Average Ambient Temperature',
#   'Average Ambient Temperature for URG3000N',
#   'Barium PM2.5 LC',
#   'Barometric pressure',
#   'Black Carbon PM2.5 at 880 nm',
#   'Bromine PM2.5 LC',
#   'Cadmium PM2.5 LC',
#   'Calcium PM2.5 LC',
#   'Cerium PM2.5 LC',
#   'Cesium PM2.5 LC',
#   'Chloride PM2.5 LC',
#   'Chlorine PM2.5 LC',
#   'Chromium PM2.5 LC',
#   'Cobalt PM2.5 LC',
#   'Copper PM2.5 LC',
#   'EC CSN_Rev Unadjusted PM2.5 LC TOR',
#   'EC CSN_Rev Unadjusted PM2.5 LC TOT',
#   'EC PM2.5 LC TOR',
#   'EC PM2.5 LC TOT',
#   'EC1 CSN_Rev Unadjusted PM2.5 LC',
#   'EC1 PM2.5 LC',
#   'EC2 CSN_Rev Unadjusted PM2.5 LC',
#   'EC2 PM2.5 LC',
#   'EC3 CSN_Rev Unadjusted PM2.5 LC',
#   'EC3 PM2.5 LC',
#   'Elapsed Sample Time',
#   'Indium PM2.5 LC',
#   'Iron PM2.5 LC',
#   'Lead PM2.5 LC',
#   'Light Absorption Coeffiecient',
#   'Magnesium PM2.5 LC',
#   'Manganese PM2.5 LC',
#   'Nickel PM2.5 LC',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'OC CSN_Rev Unadjusted PM2.5 LC TOR',
#   'OC CSN_Rev Unadjusted PM2.5 LC TOT',
#   'OC PM2.5 LC TOR',
#   'OC PM2.5 LC TOT',
#   'OC1 CSN_Rev Unadjusted PM2.5 LC',
#   'OC1 PM2.5 LC',
#   'OC2 CSN_Rev Unadjusted PM2.5 LC',
#   'OC2 PM2.5 LC',
#   'OC3 CSN_Rev Unadjusted PM2.5 LC',
#   'OC3 PM2.5 LC',
#   'OC4 CSN_Rev Unadjusted PM2.5 LC',
#   'OC4 PM2.5 LC',
#   'OP CSN_Rev Unadjusted PM2.5 LC TOR',
#   'OP CSN_Rev Unadjusted PM2.5 LC TOT',
#   'OP PM2.5 LC TOR',
#   'OP PM2.5 LC TOT',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM2.5 - Local Conditions',
#   'Phosphorus PM2.5 LC',
#   'Potassium Ion PM2.5 LC',
#   'Potassium PM2.5 LC',
#   'Reconstructed Mass PM2.5 LC',
#   'Relative Humidity ',
#   'Rubidium PM2.5 LC',
#   'Sample Flow Rate CV - Nylon Filter',
#   'Sample Flow Rate CV - Quartz Filter',
#   'Sample Flow Rate CV - Teflon Filter',
#   'Sample Flow Rate- CV',
#   'Sample Max Baro Pressure',
#   'Sample Min Baro Pressure',
#   'Sample Volume',
#   'Sample Volume - Nylon Filter',
#   'Sample Volume - Quartz Filter',
#   'Sample Volume - Teflon Filter',
#   'Selenium PM2.5 LC',
#   'Silicon PM2.5 LC',
#   'Silver PM2.5 LC',
#   'Sodium Ion Pm2.5 LC',
#   'Sodium PM2.5 LC',
#   'Soil PM2.5 LC',
#   'Solar radiation',
#   'Strontium PM2.5 LC',
#   'Sulfate PM2.5 LC',
#   'Sulfur PM2.5 LC',
#   'Tin PM2.5 LC',
#   'Titanium PM2.5 LC',
#   'Total Nitrate PM2.5 LC',
#   'Vanadium PM2.5 LC',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar',
#   'Zinc PM2.5 LC',
#   'Zirconium PM2.5 LC'},
#  'Enoch': {'Barometric pressure',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM2.5 - Local Conditions',
#   'Relative Humidity ',
#   'Solar radiation',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar'},
#  'ROSE PARK': {'Ambient Max Temperature',
#   'Ambient Min Temperature',
#   'Average Ambient Pressure',
#   'Average Ambient Temperature',
#   'Barometric pressure',
#   'Carbon monoxide',
#   'Elapsed Sample Time',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM2.5 - Local Conditions',
#   'Relative Humidity ',
#   'Sample Flow Rate- CV',
#   'Sample Max Baro Pressure',
#   'Sample Min Baro Pressure',
#   'Sample Volume',
#   'Solar radiation',
#   'Sulfur dioxide',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar'},
#  'Capitol Reef NP': {'Acceptable PM2.5 AQI & Speciation Mass',
#   'Aluminum PM2.5 LC',
#   'Ammonium Nitrate PM2.5 LC',
#   'Ammonium Sulfate PM2.5 LC',
#   'Arsenic PM2.5 LC',
#   'Bromine PM2.5 LC',
#   'Calcium PM2.5 LC',
#   'Chloride PM2.5 LC',
#   'Chlorine PM2.5 LC',
#   'Chromium PM2.5 LC',
#   'Copper PM2.5 LC',
#   'EC PM2.5 LC TOR',
#   'EC1 PM2.5 LC',
#   'EC2 PM2.5 LC',
#   'EC3 PM2.5 LC',
#   'Iron PM2.5 LC',
#   'Lead PM2.5 LC',
#   'Light Absorption Coeffiecient',
#   'Magnesium PM2.5 LC',
#   'Manganese PM2.5 LC',
#   'Nickel PM2.5 LC',
#   'Nitrite PM2.5 LC',
#   'OC PM2.5 LC TOR',
#   'OC1 PM2.5 LC',
#   'OC2 PM2.5 LC',
#   'OC3 PM2.5 LC',
#   'OC4 PM2.5 LC',
#   'OP PM2.5 LC TOR',
#   'Organic Carbon Mass PM2.5 LC',
#   'PM10 - LC',
#   'PM10-2.5 - Local Conditions',
#   'Phosphorus PM2.5 LC',
#   'Potassium PM2.5 LC',
#   'Rubidium PM2.5 LC',
#   'Selenium PM2.5 LC',
#   'Silicon PM2.5 LC',
#   'Sodium PM2.5 LC',
#   'Soil PM2.5 LC',
#   'Strontium PM2.5 LC',
#   'Sulfate PM2.5 LC',
#   'Sulfur PM2.5 LC',
#   'Titanium PM2.5 LC',
#   'Total Nitrate PM2.5 LC',
#   'Vanadium PM2.5 LC',
#   'Zinc PM2.5 LC',
#   'Zirconium PM2.5 LC'},
#  'Lake Park': {'1,2,3-Trimethylbenzene',
#   '1,2,4-Trimethylbenzene',
#   '1,3,5-Trimethylbenzene',
#   '1,3-Butadiene',
#   '1-Butene',
#   '1-Hexene',
#   '1-Pentene',
#   '2,2,4-Trimethylpentane',
#   '2,2-Dimethylbutane',
#   '2,3,4-Trimethylpentane',
#   '2,3-Dimethylbutane',
#   '2,3-Dimethylpentane',
#   '2,4-Dimethylpentane',
#   '2-Methylheptane',
#   '2-Methylhexane',
#   '2-Methylpentane',
#   '3-Methylheptane',
#   '3-Methylhexane',
#   '3-Methylpentane',
#   'Acetylene',
#   'Barometric pressure',
#   'Benzene',
#   'Black Carbon PM2.5 at 880 nm',
#   'Cyclohexane',
#   'Cyclopentane',
#   'Ethane',
#   'Ethylbenzene',
#   'Ethylene',
#   'Isobutane',
#   'Isopentane',
#   'Isoprene',
#   'Isopropylbenzene',
#   'Methylcyclohexane',
#   'Methylcyclopentane',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM10 - LC',
#   'PM10 Total 0-10um STP',
#   'PM2.5 - Local Conditions',
#   'Propane',
#   'Propylene',
#   'Relative Humidity ',
#   'Solar radiation',
#   'Styrene',
#   'Toluene',
#   'Total NMOC (non-methane organic compound)',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar',
#   'cis-2-Butene',
#   'cis-2-Pentene',
#   'm-Diethylbenzene',
#   'm-Ethyltoluene',
#   'm/p Xylene',
#   'n-Butane',
#   'n-Decane',
#   'n-Dodecane',
#   'n-Heptane',
#   'n-Hexane',
#   'n-Nonane',
#   'n-Octane',
#   'n-Pentane',
#   'n-Propylbenzene',
#   'n-Undecane',
#   'o-Ethyltoluene',
#   'o-Xylene',
#   'p-Diethylbenzene',
#   'p-Ethyltoluene',
#   'trans-2-Butene',
#   'trans-2-Pentene'},
#  'STATION LOCATED NEAR INTERSECTION OF 6000 SO & 10000 WEST': {'Barometric pressure',
#   'Net radiation',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'Peak Wind Gust',
#   'Relative Humidity ',
#   'Solar radiation',
#   'Temperature Difference',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar'},
#  'Moab': {'Barometric pressure',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM2.5 - Local Conditions',
#   'Relative Humidity ',
#   'Solar radiation',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar'},
#  'Harrisville': {'Ambient Max Temperature',
#   'Ambient Min Temperature',
#   'Average Ambient Pressure',
#   'Average Ambient Temperature',
#   'Barometric pressure',
#   'Carbon monoxide',
#   'Elapsed Sample Time',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM10 Total 0-10um STP',
#   'PM2.5 - Local Conditions',
#   'Relative Humidity ',
#   'Sample Flow Rate- CV',
#   'Sample Max Baro Pressure',
#   'Sample Min Baro Pressure',
#   'Sample Volume',
#   'Solar radiation',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar'},
#  'Spanish Fork': {'Ambient Max Temperature',
#   'Ambient Min Temperature',
#   'Average Ambient Pressure',
#   'Average Ambient Temperature',
#   'Barometric pressure',
#   'Elapsed Sample Time',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM2.5 - Local Conditions',
#   'Relative Humidity ',
#   'Sample Flow Rate- CV',
#   'Sample Max Baro Pressure',
#   'Sample Min Baro Pressure',
#   'Sample Volume',
#   'Solar radiation',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar'},
#  'Bountiful Viewmont': {'1,1,2,2-Tetrachloroethane',
#   '1,1,2-Trichloro-1,2,2-trifluoroethane',
#   '1,1,2-Trichloroethane',
#   '1,1-Dichloroethane',
#   '1,1-Dichloroethylene',
#   '1,2,3-Trimethylbenzene',
#   '1,2,4-Trichlorobenzene',
#   '1,2,4-Trimethylbenzene',
#   '1,2-Dichlorobenzene',
#   '1,2-Dichloropropane',
#   '1,3,5-Trimethylbenzene',
#   '1,3-Butadiene',
#   '1,3-Dichlorobenzene',
#   '1,4-Dichlorobenzene',
#   '1-Butene',
#   '1-Heptene',
#   '1-Hexene',
#   '1-Nonene',
#   '1-Octene',
#   '1-Pentene',
#   '1-Undecene',
#   '2,2,4-Trimethylpentane',
#   '2,2-Dimethylbutane',
#   '2,3,4-Trimethylpentane',
#   '2,3-Dimethylbutane',
#   '2,3-Dimethylpentane',
#   '2,4-Dimethylpentane',
#   '2-2-3-Trimethylpentane',
#   '2-Ethyl-1-butene',
#   '2-Methyl-1-butene',
#   '2-Methyl-1-pentene',
#   '2-Methyl-2-butene',
#   '2-Methylheptane',
#   '2-Methylhexane',
#   '2-Methylpentane',
#   '3-Methyl-1-butene',
#   '3-Methylheptane',
#   '3-Methylhexane',
#   '3-Methylpentane',
#   '4-Methyl-1-pentene',
#   'Acenaphthene (TSP) STP',
#   'Acenaphthylene (TSP) STP',
#   'Acetaldehyde',
#   'Acetone',
#   'Acetonitrile',
#   'Acetylene',
#   'Acrolein - Verified',
#   'Acrylonitrile',
#   'Aluminum PM2.5 LC',
#   'Ambient Max Temperature',
#   'Ambient Min Temperature',
#   'Ammonium Ion PM2.5 LC',
#   'Anthracene (TSP) STP',
#   'Antimony PM10 STP',
#   'Antimony PM2.5 LC',
#   'Arsenic PM10 STP',
#   'Arsenic PM2.5 LC',
#   'Average Ambient Pressure',
#   'Average Ambient Pressure for URG3000N',
#   'Average Ambient Temperature',
#   'Average Ambient Temperature for URG3000N',
#   'Barium PM2.5 LC',
#   'Barometric pressure',
#   'Benzaldehyde',
#   'Benzene',
#   'Benzo[a]anthracene (TSP) STP',
#   'Benzo[a]pyrene (TSP) STP',
#   'Benzo[b]fluoranthene (TSP) STP',
#   'Benzo[e]pyrene (TSP) STP',
#   'Benzo[g,h,i]perylene (TSP) STP',
#   'Benzo[k]fluoranthene (TSP) STP',
#   'Beryllium PM10 STP',
#   'Black Carbon PM2.5 at 880 nm',
#   'Bromine PM2.5 LC',
#   'Bromochloromethane',
#   'Bromodichloromethane',
#   'Bromoform',
#   'Bromomethane',
#   'Butyraldehyde',
#   'Cadmium PM10 STP',
#   'Cadmium PM2.5 LC',
#   'Calcium PM2.5 LC',
#   'Carbon disulfide',
#   'Carbon tetrachloride',
#   'Cerium PM2.5 LC',
#   'Cesium PM2.5 LC',
#   'Chloride PM2.5 LC',
#   'Chlorine PM2.5 LC',
#   'Chlorobenzene',
#   'Chloroethane',
#   'Chloroform',
#   'Chloromethane',
#   'Chloroprene',
#   'Chromium PM10 STP',
#   'Chromium PM2.5 LC',
#   'Chrysene (TSP) STP',
#   'Cobalt PM10 STP',
#   'Cobalt PM2.5 LC',
#   'Copper PM2.5 LC',
#   'Coronene (TSP) STP',
#   'Crotonaldehyde',
#   'Cyclohexane',
#   'Cyclopentane',
#   'Cyclopentene',
#   'Dibenzo[a,h]anthracene (TSP) STP',
#   'Dibromochloromethane',
#   'Dichlorodifluoromethane',
#   'Dichloromethane',
#   'Dodecene',
#   'EC CSN_Rev Unadjusted PM2.5 LC TOR',
#   'EC CSN_Rev Unadjusted PM2.5 LC TOT',
#   'EC PM2.5 LC TOR',
#   'EC PM2.5 LC TOT',
#   'EC1 CSN_Rev Unadjusted PM2.5 LC',
#   'EC1 PM2.5 LC',
#   'EC2 CSN_Rev Unadjusted PM2.5 LC',
#   'EC2 PM2.5 LC',
#   'EC3 CSN_Rev Unadjusted PM2.5 LC',
#   'EC3 PM2.5 LC',
#   'Elapsed Sample Time',
#   'Ethane',
#   'Ethyl acrylate',
#   'Ethylbenzene',
#   'Ethylene',
#   'Ethylene dibromide',
#   'Ethylene dichloride',
#   'Ethylene oxide',
#   'Fluoranthene (TSP) STP',
#   'Fluorene (TSP) STP',
#   'Formaldehyde',
#   'Freon 114',
#   'Hexachlorobutadiene',
#   'Hexanaldehyde',
#   'Indeno[1,2,3-cd]pyrene (TSP) STP',
#   'Indium PM2.5 LC',
#   'Iron PM2.5 LC',
#   'Isobutane',
#   'Isobutene',
#   'Isopentane',
#   'Isoprene',
#   'Isopropylbenzene',
#   'Lead PM10 STP',
#   'Lead PM2.5 LC',
#   'Light Absorption Coeffiecient',
#   'Magnesium PM2.5 LC',
#   'Manganese PM10 STP',
#   'Manganese PM2.5 LC',
#   'Methyl chloroform',
#   'Methyl ethyl ketone',
#   'Methyl isobutyl ketone',
#   'Methyl methacrylate',
#   'Methyl tert-butyl ether',
#   'Methylcyclohexane',
#   'Methylcyclopentane',
#   'NOy - NO',
#   'Naphthalene (TSP) STP',
#   'Nickel PM10 STP',
#   'Nickel PM2.5 LC',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'OC CSN_Rev Unadjusted PM2.5 LC TOR',
#   'OC CSN_Rev Unadjusted PM2.5 LC TOT',
#   'OC PM2.5 LC TOR',
#   'OC PM2.5 LC TOT',
#   'OC1 CSN_Rev Unadjusted PM2.5 LC',
#   'OC1 PM2.5 LC',
#   'OC2 CSN_Rev Unadjusted PM2.5 LC',
#   'OC2 PM2.5 LC',
#   'OC3 CSN_Rev Unadjusted PM2.5 LC',
#   'OC3 PM2.5 LC',
#   'OC4 CSN_Rev Unadjusted PM2.5 LC',
#   'OC4 PM2.5 LC',
#   'OP CSN_Rev Unadjusted PM2.5 LC TOR',
#   'OP CSN_Rev Unadjusted PM2.5 LC TOT',
#   'OP PM2.5 LC TOR',
#   'OP PM2.5 LC TOT',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM10 - LC',
#   'PM10 Total 0-10um STP',
#   'PM2.5 - Local Conditions',
#   'Perylene (TSP) STP',
#   'Phenanthrene (TSP) STP',
#   'Phosphorus PM2.5 LC',
#   'Potassium Ion PM2.5 LC',
#   'Potassium PM2.5 LC',
#   'Propane',
#   'Propionaldehyde',
#   'Propylene',
#   'Propyne',
#   'Pyrene (TSP) STP',
#   'Reactive oxides of nitrogen (NOy)',
#   'Reconstructed Mass PM2.5 LC',
#   'Relative Humidity ',
#   'Rubidium PM2.5 LC',
#   'Sample Flow Rate CV - Nylon Filter',
#   'Sample Flow Rate CV - Quartz Filter',
#   'Sample Flow Rate CV - Teflon Filter',
#   'Sample Flow Rate- CV',
#   'Sample Max Baro Pressure',
#   'Sample Min Baro Pressure',
#   'Sample Volume',
#   'Sample Volume - Nylon Filter',
#   'Sample Volume - Quartz Filter',
#   'Sample Volume - Teflon Filter',
#   'Selenium PM10 STP',
#   'Selenium PM2.5 LC',
#   'Silicon PM2.5 LC',
#   'Silver PM2.5 LC',
#   'Sodium Ion Pm2.5 LC',
#   'Sodium PM2.5 LC',
#   'Soil PM2.5 LC',
#   'Solar radiation',
#   'Strontium PM2.5 LC',
#   'Styrene',
#   'Sulfate PM2.5 LC',
#   'Sulfur PM2.5 LC',
#   'Tert-amyl methyl ether',
#   'Tetrachloroethylene',
#   'Tin PM2.5 LC',
#   'Titanium PM2.5 LC',
#   'Toluene',
#   'Total NMOC (non-methane organic compound)',
#   'Total Nitrate PM2.5 LC',
#   'Trichloroethylene',
#   'Trichlorofluoromethane',
#   'Tridecene',
#   'Valeraldehyde',
#   'Vanadium PM2.5 LC',
#   'Vinyl chloride',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar',
#   'Zinc PM2.5 LC',
#   'Zirconium PM2.5 LC',
#   'alpha.-Pinene',
#   'beta.-Pinene',
#   'cis-1,2-Dichloroethene',
#   'cis-1,3-Dichloropropene',
#   'cis-2-Butene',
#   'cis-2-Hexene',
#   'cis-2-Pentene',
#   'm-Diethylbenzene',
#   'm-Ethyltoluene',
#   'm/p Xylene',
#   'n-Butane',
#   'n-Decane',
#   'n-Dodecane',
#   'n-Heptane',
#   'n-Hexane',
#   'n-Nonane',
#   'n-Octane',
#   'n-Pentane',
#   'n-Propylbenzene',
#   'n-Tridecane',
#   'n-Undecane',
#   'o-Ethyltoluene',
#   'o-Xylene',
#   'p-Diethylbenzene',
#   'p-Ethyltoluene',
#   'tert-Butyl ethyl ether',
#   'trans-1,2-Dichloroethylene',
#   'trans-1,3-Dichloropropene',
#   'trans-2-Butene',
#   'trans-2-Hexene',
#   'trans-2-Pentene'},
#  'Price #2': {'Barometric pressure',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM2.5 - Local Conditions',
#   'Relative Humidity ',
#   'Solar radiation',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar'},
#  'Red Butte': {'1,2,3-Trimethylbenzene',
#   '1,2,4-Trimethylbenzene',
#   '1,3,5-Trimethylbenzene',
#   '1,3-Butadiene',
#   '1-Butene',
#   '1-Hexene',
#   '1-Pentene',
#   '2,2,4-Trimethylpentane',
#   '2,2-Dimethylbutane',
#   '2,3,4-Trimethylpentane',
#   '2,3-Dimethylbutane',
#   '2,3-Dimethylpentane',
#   '2,4-Dimethylpentane',
#   '2-Methylheptane',
#   '2-Methylhexane',
#   '2-Methylpentane',
#   '3-Methylheptane',
#   '3-Methylhexane',
#   '3-Methylpentane',
#   'Acetylene',
#   'Barometric pressure',
#   'Benzene',
#   'Cyclohexane',
#   'Cyclopentane',
#   'Ethane',
#   'Ethylbenzene',
#   'Ethylene',
#   'Isobutane',
#   'Isopentane',
#   'Isoprene',
#   'Isopropylbenzene',
#   'Methylcyclohexane',
#   'Methylcyclopentane',
#   'Mixing Height',
#   'NOy - NO',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'PM2.5 - Local Conditions',
#   'Propane',
#   'Propylene',
#   'Reactive oxides of nitrogen (NOy)',
#   'Relative Humidity ',
#   'Solar radiation',
#   'Styrene',
#   'Toluene',
#   'Total NMOC (non-methane organic compound)',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar',
#   'cis-2-Butene',
#   'cis-2-Pentene',
#   'm-Diethylbenzene',
#   'm-Ethyltoluene',
#   'm/p Xylene',
#   'n-Butane',
#   'n-Decane',
#   'n-Dodecane',
#   'n-Heptane',
#   'n-Hexane',
#   'n-Nonane',
#   'n-Octane',
#   'n-Pentane',
#   'n-Propylbenzene',
#   'n-Undecane',
#   'o-Ethyltoluene',
#   'o-Xylene',
#   'p-Diethylbenzene',
#   'p-Ethyltoluene',
#   'trans-2-Butene',
#   'trans-2-Pentene'},
#  'Dinosaur NM': {'Acceptable PM2.5 AQI & Speciation Mass',
#   'Aluminum PM2.5 LC',
#   'Ammonium Nitrate PM2.5 LC',
#   'Ammonium Sulfate PM2.5 LC',
#   'Arsenic PM2.5 LC',
#   'Bromine PM2.5 LC',
#   'Calcium PM2.5 LC',
#   'Chloride PM2.5 LC',
#   'Chlorine PM2.5 LC',
#   'Chromium PM2.5 LC',
#   'Copper PM2.5 LC',
#   'EC PM2.5 LC TOR',
#   'EC1 PM2.5 LC',
#   'EC2 PM2.5 LC',
#   'EC3 PM2.5 LC',
#   'Iron PM2.5 LC',
#   'Lead PM2.5 LC',
#   'Light Absorption Coeffiecient',
#   'Magnesium PM2.5 LC',
#   'Manganese PM2.5 LC',
#   'Nickel PM2.5 LC',
#   'Nitrite PM2.5 LC',
#   'OC PM2.5 LC TOR',
#   'OC1 PM2.5 LC',
#   'OC2 PM2.5 LC',
#   'OC3 PM2.5 LC',
#   'OC4 PM2.5 LC',
#   'OP PM2.5 LC TOR',
#   'Organic Carbon Mass PM2.5 LC',
#   'PM10 - LC',
#   'PM10-2.5 - Local Conditions',
#   'Phosphorus PM2.5 LC',
#   'Potassium PM2.5 LC',
#   'Rubidium PM2.5 LC',
#   'Selenium PM2.5 LC',
#   'Silicon PM2.5 LC',
#   'Sodium PM2.5 LC',
#   'Soil PM2.5 LC',
#   'Strontium PM2.5 LC',
#   'Sulfate PM2.5 LC',
#   'Sulfur PM2.5 LC',
#   'Titanium PM2.5 LC',
#   'Total Nitrate PM2.5 LC',
#   'Vanadium PM2.5 LC',
#   'Zinc PM2.5 LC',
#   'Zirconium PM2.5 LC'},
#  'WASHAKIE': {'Barometric pressure',
#   'Nitric oxide (NO)',
#   'Nitrogen dioxide (NO2)',
#   'Outdoor Temperature',
#   'Oxides of nitrogen (NOx)',
#   'Ozone',
#   'Relative Humidity ',
#   'Solar radiation',
#   'Wind Direction - Resultant',
#   'Wind Speed - Scalar'},
#  'Antelope Island': {'Outdoor Temperature',
#   'Relative Humidity ',
#   'Wind Direction - Scalar',
#   'Wind Speed - Scalar'}}

# %%
ozone = pd.read_csv("daily_44201_2025.csv")
# Out:
# C:\Users\jmei7\AppData\Local\Temp\ipykernel_23256\3688438501.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   ozone = pd.read_csv("daily_44201_2025.csv")

# %%
ozone.head()
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1            3        10           44201    1  30.497478
# 1           1            3        10           44201    1  30.497478
# 2           1            3        10           44201    1  30.497478
# 3           1            3        10           44201    1  30.497478
# 4           1            3        10           44201    1  30.497478
#
#    Longitude  Datum Parameter Name          Sample Duration  ...   AQI  \
# 0 -87.880258  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR  ...   6.0
# 1 -87.880258  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR  ...  61.0
# 2 -87.880258  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR  ...  44.0
# 3 -87.880258  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR  ...  44.0
# 4 -87.880258  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR  ...  45.0
#
#   Method Code                             Method Name    Local Site Name  \
# 0          87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  FAIRHOPE, Alabama
# 1          87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  FAIRHOPE, Alabama
# 2          87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  FAIRHOPE, Alabama
# 3          87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  FAIRHOPE, Alabama
# 4          87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  FAIRHOPE, Alabama
#
#                                              Address  State Name  County Name  \
# 0  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...     Alabama      Baldwin
# 1  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...     Alabama      Baldwin
# 2  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...     Alabama      Baldwin
# 3  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...     Alabama      Baldwin
# 4  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...     Alabama      Baldwin
#
#    City Name                  CBSA Name  Date of Last Change
# 0   Fairhope  Daphne-Fairhope-Foley, AL           2025-10-29
# 1   Fairhope  Daphne-Fairhope-Foley, AL           2025-10-29
# 2   Fairhope  Daphne-Fairhope-Foley, AL           2025-10-29
# 3   Fairhope  Daphne-Fairhope-Foley, AL           2025-10-29
# 4   Fairhope  Daphne-Fairhope-Foley, AL           2025-10-29
#
# [5 rows x 29 columns]

# %%
co = pd.read_csv("daily_42101_2025.csv")
# Out:
# C:\Users\jmei7\AppData\Local\Temp\ipykernel_23256\859686527.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   co = pd.read_csv("daily_42101_2025.csv")

# %%
co.head()
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1           73        23           42101    2  33.553056
# 1           1           73        23           42101    2  33.553056
# 2           1           73        23           42101    2  33.553056
# 3           1           73        23           42101    2  33.553056
# 4           1           73        23           42101    2  33.553056
#
#    Longitude  Datum   Parameter Name Sample Duration  ... AQI Method Code  \
# 0    -86.815  WGS84  Carbon monoxide          1 HOUR  ... NaN          93
# 1    -86.815  WGS84  Carbon monoxide          1 HOUR  ... NaN          93
# 2    -86.815  WGS84  Carbon monoxide          1 HOUR  ... NaN          93
# 3    -86.815  WGS84  Carbon monoxide          1 HOUR  ... NaN          93
# 4    -86.815  WGS84  Carbon monoxide          1 HOUR  ... NaN          93
#
#                                          Method Name   Local Site Name  \
# 0  INSTRUMENTAL - GAS FILTER CORRELATION CO ANALYZER  North Birmingham
# 1  INSTRUMENTAL - GAS FILTER CORRELATION CO ANALYZER  North Birmingham
# 2  INSTRUMENTAL - GAS FILTER CORRELATION CO ANALYZER  North Birmingham
# 3  INSTRUMENTAL - GAS FILTER CORRELATION CO ANALYZER  North Birmingham
# 4  INSTRUMENTAL - GAS FILTER CORRELATION CO ANALYZER  North Birmingham
#
#                                  Address  State Name  County Name   City Name  \
# 0  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.     Alabama    Jefferson  Birmingham
# 1  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.     Alabama    Jefferson  Birmingham
# 2  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.     Alabama    Jefferson  Birmingham
# 3  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.     Alabama    Jefferson  Birmingham
# 4  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.     Alabama    Jefferson  Birmingham
#
#                CBSA Name  Date of Last Change
# 0  Birmingham-Hoover, AL           2025-10-01
# 1  Birmingham-Hoover, AL           2025-10-01
# 2  Birmingham-Hoover, AL           2025-10-01
# 3  Birmingham-Hoover, AL           2025-10-01
# 4  Birmingham-Hoover, AL           2025-10-01
#
# [5 rows x 29 columns]

# %%
no2 = pd.read_csv("daily_42602_2025.csv")
# Out:
# C:\Users\jmei7\AppData\Local\Temp\ipykernel_23256\3336421117.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   no2 = pd.read_csv("daily_42602_2025.csv")

# %%
no2.head()
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1           73        23           42602    1  33.553056
# 1           1           73        23           42602    1  33.553056
# 2           1           73        23           42602    1  33.553056
# 3           1           73        23           42602    1  33.553056
# 4           1           73        23           42602    1  33.553056
#
#    Longitude  Datum          Parameter Name Sample Duration  ... AQI  \
# 0    -86.815  WGS84  Nitrogen dioxide (NO2)          1 HOUR  ...  31
# 1    -86.815  WGS84  Nitrogen dioxide (NO2)          1 HOUR  ...  32
# 2    -86.815  WGS84  Nitrogen dioxide (NO2)          1 HOUR  ...  35
# 3    -86.815  WGS84  Nitrogen dioxide (NO2)          1 HOUR  ...  12
# 4    -86.815  WGS84  Nitrogen dioxide (NO2)          1 HOUR  ...  11
#
#   Method Code                                        Method Name  \
# 0         200  Teledyne-API Model 200EUP or T200UP - Photolyt...
# 1         200  Teledyne-API Model 200EUP or T200UP - Photolyt...
# 2         200  Teledyne-API Model 200EUP or T200UP - Photolyt...
# 3         200  Teledyne-API Model 200EUP or T200UP - Photolyt...
# 4         200  Teledyne-API Model 200EUP or T200UP - Photolyt...
#
#     Local Site Name                                Address  State Name  \
# 0  North Birmingham  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.     Alabama
# 1  North Birmingham  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.     Alabama
# 2  North Birmingham  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.     Alabama
# 3  North Birmingham  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.     Alabama
# 4  North Birmingham  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.     Alabama
#
#    County Name   City Name              CBSA Name  Date of Last Change
# 0    Jefferson  Birmingham  Birmingham-Hoover, AL           2025-10-08
# 1    Jefferson  Birmingham  Birmingham-Hoover, AL           2025-10-08
# 2    Jefferson  Birmingham  Birmingham-Hoover, AL           2025-10-08
# 3    Jefferson  Birmingham  Birmingham-Hoover, AL           2025-10-08
# 4    Jefferson  Birmingham  Birmingham-Hoover, AL           2025-10-08
#
# [5 rows x 29 columns]

# %%
so2 = pd.read_csv("daily_42401_2025.csv")
# Out:
# C:\Users\jmei7\AppData\Local\Temp\ipykernel_23256\1945579195.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   so2 = pd.read_csv("daily_42401_2025.csv")

# %%
so2.head()
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1           73        23           42401    2  33.553056
# 1           1           73        23           42401    2  33.553056
# 2           1           73        23           42401    2  33.553056
# 3           1           73        23           42401    2  33.553056
# 4           1           73        23           42401    2  33.553056
#
#    Longitude  Datum  Parameter Name Sample Duration  ...  AQI Method Code  \
# 0    -86.815  WGS84  Sulfur dioxide          1 HOUR  ...  0.0         100
# 1    -86.815  WGS84  Sulfur dioxide          1 HOUR  ...  4.0         100
# 2    -86.815  WGS84  Sulfur dioxide          1 HOUR  ...  3.0         100
# 3    -86.815  WGS84  Sulfur dioxide          1 HOUR  ...  1.0         100
# 4    -86.815  WGS84  Sulfur dioxide          1 HOUR  ...  1.0         100
#
#                                Method Name   Local Site Name  \
# 0  INSTRUMENTAL - ULTRAVIOLET FLUORESCENCE  North Birmingham
# 1  INSTRUMENTAL - ULTRAVIOLET FLUORESCENCE  North Birmingham
# 2  INSTRUMENTAL - ULTRAVIOLET FLUORESCENCE  North Birmingham
# 3  INSTRUMENTAL - ULTRAVIOLET FLUORESCENCE  North Birmingham
# 4  INSTRUMENTAL - ULTRAVIOLET FLUORESCENCE  North Birmingham
#
#                                  Address  State Name  County Name   City Name  \
# 0  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.     Alabama    Jefferson  Birmingham
# 1  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.     Alabama    Jefferson  Birmingham
# 2  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.     Alabama    Jefferson  Birmingham
# 3  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.     Alabama    Jefferson  Birmingham
# 4  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.     Alabama    Jefferson  Birmingham
#
#                CBSA Name  Date of Last Change
# 0  Birmingham-Hoover, AL           2025-10-02
# 1  Birmingham-Hoover, AL           2025-10-02
# 2  Birmingham-Hoover, AL           2025-10-02
# 3  Birmingham-Hoover, AL           2025-10-02
# 4  Birmingham-Hoover, AL           2025-10-02
#
# [5 rows x 29 columns]

# %%
print(ozone.columns == co.columns)
print(ozone.columns == no2.columns)
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True]

# %%
# join on date, location (cbsa, ignore location if absent)

# %%
all_param = pd.concat([ozone, co, no2, so2])

# %%
len(all_param)
# Out:
# 598171

# %%
all_param.columns
# Out:
# Index(['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Sample Duration',
#        'Pollutant Standard', 'Date Local', 'Units of Measure', 'Event Type',
#        'Observation Count', 'Observation Percent', 'Arithmetic Mean',
#        '1st Max Value', '1st Max Hour', 'AQI', 'Method Code', 'Method Name',
#        'Local Site Name', 'Address', 'State Name', 'County Name', 'City Name',
#        'CBSA Name', 'Date of Last Change'],
#       dtype='object')

# %%
set(all_param['CBSA Name'])
# Out:
# {'Adrian, MI',
#  'Akron, OH',
#  'Albany-Schenectady-Troy, NY',
#  'Albuquerque, NM',
#  'Allentown-Bethlehem-Easton, PA-NJ',
#  'Altoona, PA',
#  'Amarillo, TX',
#  'Anchorage, AK',
#  'Ann Arbor, MI',
#  'Appleton, WI',
#  'Ardmore, OK',
#  'Arkadelphia, AR',
#  'Asheville, NC',
#  'Ashtabula, OH',
#  'Athens-Clarke County, GA',
#  'Atlanta-Sandy Springs-Roswell, GA',
#  'Atlantic City-Hammonton, NJ',
#  'Augusta-Richmond County, GA-SC',
#  'Augusta-Waterville, ME',
#  'Austin-Round Rock, TX',
#  'Bakersfield, CA',
#  'Baltimore-Columbia-Towson, MD',
#  'Bangor, ME',
#  'Baraboo, WI',
#  'Barnstable Town, MA',
#  'Bartlesville, OK',
#  'Baton Rouge, LA',
#  'Beaumont-Port Arthur, TX',
#  'Beaver Dam, WI',
#  'Bellingham, WA',
#  'Bemidji, MN',
#  'Bennington, VT',
#  'Berlin, NH-VT',
#  'Big Spring, TX',
#  'Billings, MT',
#  'Birmingham-Hoover, AL',
#  'Bishop, CA',
#  'Bismarck, ND',
#  'Blacksburg-Christiansburg-Radford, VA',
#  'Bloomington, IL',
#  'Bloomington, IN',
#  'Boise City, ID',
#  'Borger, TX',
#  'Boston-Cambridge-Newton, MA-NH',
#  'Boulder, CO',
#  'Bowling Green, KY',
#  'Bozeman, MT',
#  'Brainerd, MN',
#  'Bridgeport-Stamford-Norwalk, CT',
#  'Brookings, SD',
#  'Brownsville-Harlingen, TX',
#  'Brunswick, GA',
#  'Buffalo-Cheektowaga-Niagara Falls, NY',
#  'Burlington-South Burlington, VT',
#  'Cadillac, MI',
#  'Cambridge, MD',
#  'Canton-Massillon, OH',
#  'Cape Coral-Fort Myers, FL',
#  'Carlsbad-Artesia, NM',
#  'Carson City, NV',
#  'Casper, WY',
#  'Cedar City, UT',
#  'Cedar Rapids, IA',
#  'Chambersburg-Waynesboro, PA',
#  'Champaign-Urbana, IL',
#  'Charleston, WV',
#  'Charleston-North Charleston, SC',
#  'Charlotte-Concord-Gastonia, NC-SC',
#  'Charlottesville, VA',
#  'Chattanooga, TN-GA',
#  'Cheyenne, WY',
#  'Chicago-Naperville-Elgin, IL-IN-WI',
#  'Chico, CA',
#  'Cincinnati, OH-KY-IN',
#  'Claremont-Lebanon, NH-VT',
#  'Clarksville, TN-KY',
#  'Cleveland, MS',
#  'Cleveland-Elyria, OH',
#  'Clinton, IA',
#  'Coco, PR',
#  'College Station-Bryan, TX',
#  'Colorado Springs, CO',
#  'Columbia, MO',
#  'Columbia, SC',
#  'Columbus, GA-AL',
#  'Columbus, IN',
#  'Columbus, OH',
#  'Concord, NH',
#  'Corning, NY',
#  'Corpus Christi, TX',
#  'Corsicana, TX',
#  'Crestview-Fort Walton Beach-Destin, FL',
#  'Dallas-Fort Worth-Arlington, TX',
#  'Dalton, GA',
#  'Daphne-Fairhope-Foley, AL',
#  'Davenport-Moline-Rock Island, IA-IL',
#  'Dayton, OH',
#  'Decatur, AL',
#  'Decatur, IL',
#  'Deltona-Daytona Beach-Ormond Beach, FL',
#  'Denver-Aurora-Lakewood, CO',
#  'Des Moines-West Des Moines, IA',
#  'Detroit-Warren-Dearborn, MI',
#  'Dickinson, ND',
#  'Dover, DE',
#  'Duluth, MN-WI',
#  'Durango, CO',
#  'Durham-Chapel Hill, NC',
#  'East Stroudsburg, PA',
#  'Eau Claire, WI',
#  'Effingham, IL',
#  'El Centro, CA',
#  'El Paso, TX',
#  'Elizabethtown-Fort Knox, KY',
#  'Elkhart-Goshen, IN',
#  'Enid, OK',
#  'Erie, PA',
#  'Espa¤ola, NM',
#  'Eugene, OR',
#  'Eureka-Arcata-Fortuna, CA',
#  'Evansville, IN-KY',
#  'Fairbanks, AK',
#  'Fallon, NV',
#  'Fargo, ND-MN',
#  'Farmington, NM',
#  'Fayetteville, NC',
#  'Fayetteville-Springdale-Rogers, AR-MO',
#  'Fernley, NV',
#  'Findlay, OH',
#  'Flagstaff, AZ',
#  'Flint, MI',
#  'Florence, SC',
#  'Fond du Lac, WI',
#  'Fort Collins, CO',
#  'Fort Payne, AL',
#  'Fort Smith, AR-OK',
#  'Fort Wayne, IN',
#  'Fresno, CA',
#  'Gadsden, AL',
#  'Gainesville, FL',
#  'Gettysburg, PA',
#  'Gillette, WY',
#  'Glenwood Springs, CO',
#  'Grand Island, NE',
#  'Grand Junction, CO',
#  'Grand Rapids-Wyoming, MI',
#  'Greeley, CO',
#  'Green Bay, WI',
#  'Greenfield Town, MA',
#  'Greensboro-High Point, NC',
#  'Greenville, NC',
#  'Greenville-Anderson-Mauldin, SC',
#  'Gulfport-Biloxi-Pascagoula, MS',
#  'Hagerstown-Martinsburg, MD-WV',
#  'Hanford-Corcoran, CA',
#  'Harrisburg-Carlisle, PA',
#  'Harrison, AR',
#  'Harrisonburg, VA',
#  'Hartford-West Hartford-East Hartford, CT',
#  'Heber, UT',
#  'Helena, MT',
#  'Hermiston-Pendleton, OR',
#  'Hickory-Lenoir-Morganton, NC',
#  'Hilo, HI',
#  'Hobbs, NM',
#  'Holland, MI',
#  'Homosassa Springs, FL',
#  'Houma-Thibodaux, LA',
#  'Houston-The Woodlands-Sugar Land, TX',
#  'Huntington-Ashland, WV-KY-OH',
#  'Huntsville, AL',
#  'Idaho Falls, ID',
#  'Indiana, PA',
#  'Indianapolis-Carmel-Anderson, IN',
#  'Ithaca, NY',
#  'Jackson, MS',
#  'Jackson, WY-ID',
#  'Jacksonville, FL',
#  'Jamestown-Dunkirk-Fredonia, NY',
#  'Janesville-Beloit, WI',
#  'Jefferson City, MO',
#  'Johnstown, PA',
#  'Joplin, MO',
#  'Kalamazoo-Portage, MI',
#  'Kalispell, MT',
#  'Kansas City, MO-KS',
#  'Kapaa, HI',
#  'Keene, NH',
#  'Kennewick-Richland, WA',
#  'Killeen-Temple, TX',
#  'Kingsport-Bristol-Bristol, TN-VA',
#  'Kinston, NC',
#  'Knoxville, TN',
#  'Kokomo, IN',
#  'La Crosse-Onalaska, WI-MN',
#  'Laconia, NH',
#  'Lafayette, LA',
#  'Lafayette-West Lafayette, IN',
#  'Lake Charles, LA',
#  'Lake City, FL',
#  'Lakeland-Winter Haven, FL',
#  'Lancaster, PA',
#  'Lansing-East Lansing, MI',
#  'Laramie, WY',
#  'Laredo, TX',
#  'Las Cruces, NM',
#  'Las Vegas-Henderson-Paradise, NV',
#  'Lawrence, KS',
#  'Lawton, OK',
#  'Lebanon, PA',
#  'Lewiston-Auburn, ME',
#  'Lexington-Fayette, KY',
#  'Lima, OH',
#  'Lincoln, NE',
#  'Little Rock-North Little Rock-Conway, AR',
#  'Logan, UT-ID',
#  'Longview, TX',
#  'Los Angeles-Long Beach-Anaheim, CA',
#  'Louisville/Jefferson County, KY-IN',
#  'Ludington, MI',
#  'Macon, GA',
#  'Madera, CA',
#  'Madison, WI',
#  'Manchester-Nashua, NH',
#  'Manitowoc, WI',
#  'Mankato-North Mankato, MN',
#  'Marietta, OH',
#  'Marshall, MN',
#  'Marshall, TX',
#  'Mayaguez, PR',
#  'McAlester, OK',
#  'McAllen-Edinburg-Mission, TX',
#  'Medford, OR',
#  'Memphis, TN-MS-AR',
#  'Merced, CA',
#  'Meridian, MS',
#  'Miami, OK',
#  'Miami-Fort Lauderdale-West Palm Beach, FL',
#  'Michigan City-La Porte, IN',
#  'Middlesborough, KY',
#  'Milwaukee-Waukesha-West Allis, WI',
#  'Minneapolis-St. Paul-Bloomington, MN-WI',
#  'Minot, ND',
#  'Missoula, MT',
#  'Mobile, AL',
#  'Modesto, CA',
#  'Monroe, LA',
#  'Montgomery, AL',
#  'Morehead City, NC',
#  'Morgantown, WV',
#  'Morristown, TN',
#  'Mount Pleasant, TX',
#  'Mount Vernon, IL',
#  'Mount Vernon, OH',
#  'Muncie, IN',
#  'Muscatine, IA',
#  'Muskegon, MI',
#  'Myrtle Beach-Conway-North Myrtle Beach, SC-NC',
#  'Naples-Immokalee-Marco Island, FL',
#  'Nashville-Davidson--Murfreesboro--Franklin, TN',
#  'New Haven-Milford, CT',
#  'New Orleans-Metairie, LA',
#  'New York-Newark-Jersey City, NY-NJ-PA',
#  'Niles-Benton Harbor, MI',
#  'North Port-Sarasota-Bradenton, FL',
#  'Norwich-New London, CT',
#  'Ocala, FL',
#  'Ogden-Clearfield, UT',
#  'Ogdensburg-Massena, NY',
#  'Oklahoma City, OK',
#  'Olympia-Tumwater, WA',
#  'Omaha-Council Bluffs, NE-IA',
#  'Orlando-Kissimmee-Sanford, FL',
#  'Ottawa-Peru, IL',
#  'Owensboro, KY',
#  'Oxford, NC',
#  'Oxnard-Thousand Oaks-Ventura, CA',
#  'Paducah, KY-IL',
#  'Palatka, FL',
#  'Palm Bay-Melbourne-Titusville, FL',
#  'Panama City, FL',
#  'Parkersburg-Vienna, WV',
#  'Payson, AZ',
#  'Pensacola-Ferry Pass-Brent, FL',
#  'Peoria, IL',
#  'Philadelphia-Camden-Wilmington, PA-NJ-DE-MD',
#  'Phoenix-Mesa-Scottsdale, AZ',
#  'Pittsburgh, PA',
#  'Pittsfield, MA',
#  'Pocatello, ID',
#  'Point Pleasant, WV-OH',
#  'Ponca City, OK',
#  'Ponce, PR',
#  'Port Angeles, WA',
#  'Port St. Lucie, FL',
#  'Portland-South Portland, ME',
#  'Portland-Vancouver-Hillsboro, OR-WA',
#  'Portsmouth, OH',
#  'Prescott, AZ',
#  'Price, UT',
#  'Providence-Warwick, RI-MA',
#  'Provo-Orem, UT',
#  'Pueblo, CO',
#  'Quincy, IL-MO',
#  'Racine, WI',
#  'Raleigh, NC',
#  'Rapid City, SD',
#  'Reading, PA',
#  'Red Bluff, CA',
#  'Red Wing, MN',
#  'Redding, CA',
#  'Reno, NV',
#  'Richmond, VA',
#  'Riverside-San Bernardino-Ontario, CA',
#  'Riverton, WY',
#  'Roanoke, VA',
#  'Rochester, MN',
#  'Rochester, NY',
#  'Rock Springs, WY',
#  'Rockford, IL',
#  'Rockland, ME',
#  'Rocky Mount, NC',
#  'Rutland, VT',
#  'Sacramento--Roseville--Arden-Arcade, CA',
#  'Salem, OR',
#  'Salinas, CA',
#  'Salisbury, MD-DE',
#  'Salt Lake City, UT',
#  'San Antonio-New Braunfels, TX',
#  'San Diego-Carlsbad, CA',
#  'San Jose-Sunnyvale-Santa Clara, CA',
#  'San Juan-Carolina-Caguas, PR',
#  'San Luis Obispo-Paso Robles-Arroyo Grande, CA',
#  'Santa Cruz-Watsonville, CA',
#  'Santa Fe, NM',
#  'Santa Maria-Santa Barbara, CA',
#  'Savannah, GA',
#  'Sayre, PA',
#  'Scranton--Wilkes-Barre--Hazleton, PA',
#  'Seattle-Tacoma-Bellevue, WA',
#  'Sebastian-Vero Beach, FL',
#  'Sebring, FL',
#  'Sevierville, TN',
#  'Sheboygan, WI',
#  'Sheridan, WY',
#  'Shreveport-Bossier City, LA',
#  'Sierra Vista-Douglas, AZ',
#  'Sioux City, IA-NE-SD',
#  'Sioux Falls, SD',
#  'Somerset, KY',
#  'Somerset, PA',
#  'Sonora, CA',
#  'South Bend-Mishawaka, IN-MI',
#  'Spartanburg, SC',
#  'Spokane-Spokane Valley, WA',
#  'Springfield, IL',
#  'Springfield, MA',
#  'Springfield, MO',
#  'Springfield, OH',
#  'St. Cloud, MN',
#  'St. George, UT',
#  'St. Joseph, MO-KS',
#  'St. Louis, MO-IL',
#  'St. Marys, PA',
#  'State College, PA',
#  'Stockton-Lodi, CA',
#  'Syracuse, NY',
#  'Tallahassee, FL',
#  'Tampa-St. Petersburg-Clearwater, FL',
#  'Terre Haute, IN',
#  'Toledo, OH',
#  'Topeka, KS',
#  'Torrington, CT',
#  'Traverse City, MI',
#  'Trenton, NJ',
#  'Truckee-Grass Valley, CA',
#  'Tucson, AZ',
#  'Tulsa, OK',
#  'Tupelo, MS',
#  'Tuscaloosa, AL',
#  'Tyler, TX',
#  'Urban Honolulu, HI',
#  'Vallejo-Fairfield, CA',
#  'Vermillion, SD',
#  'Vernal, UT',
#  'Victoria, TX',
#  'Vincennes, IN',
#  'Vineland-Bridgeton, NJ',
#  'Vineyard Haven, MA',
#  'Virginia Beach-Norfolk-Newport News, VA-NC',
#  'Visalia-Porterville, CA',
#  'Wabash, IN',
#  'Waco, TX',
#  'Walla Walla, WA',
#  'Warren, PA',
#  'Washington, NC',
#  'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#  'Waterloo-Cedar Falls, IA',
#  'Watertown, SD',
#  'Watertown-Fort Atkinson, WI',
#  'Watertown-Fort Drum, NY',
#  'Wausau, WI',
#  'Weirton-Steubenville, WV-OH',
#  'Wheeling, WV-OH',
#  'Whitewater-Elkhorn, WI',
#  'Wichita, KS',
#  'Williamsport, PA',
#  'Williston, ND',
#  'Wilmington, NC',
#  'Wilmington, OH',
#  'Winchester, VA-WV',
#  'Winston-Salem, NC',
#  'Worcester, MA-CT',
#  'York-Hanover, PA',
#  'Youngstown-Warren-Boardman, OH-PA',
#  'Yuba City, CA',
#  'Yuma, AZ',
#  nan}

# %%
all_param.sort_values("Date Local").head()
# Out:
#        State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 58201          12           57        81           44201    1  27.740033
# 47948          34           39         4           42602    2  40.641440
# 47612           8           69        11           44201    1  40.592543
# 43962          26          163        99           42101    1  42.295824
# 25832           6           61         3           44201    1  38.935680
#
#         Longitude  Datum          Parameter Name          Sample Duration  \
# 58201  -82.465146  WGS84                   Ozone  8-HR RUN AVG BEGIN HOUR
# 47948  -74.208365  WGS84  Nitrogen dioxide (NO2)                   1 HOUR
# 47612 -105.141122  WGS84                   Ozone  8-HR RUN AVG BEGIN HOUR
# 43962  -83.129431  WGS84         Carbon monoxide    8-HR RUN AVG END HOUR
# 25832 -121.099590  NAD83                   Ozone  8-HR RUN AVG BEGIN HOUR
#
#        ...   AQI Method Code  \
# 58201  ...  37.0          47
# 47948  ...  30.0          74
# 47612  ...  25.0         199
# 43962  ...   2.0          54
# 25832  ...  18.0          87
#
#                                              Method Name  \
# 58201                        INSTRUMENTAL - ULTRA VIOLET
# 47948                   INSTRUMENTAL - CHEMILUMINESCENCE
# 47612  Instrumental - Chemiluminescence API Model 265...
# 43962              INSTRUMENTAL - NONDISPERSIVE INFRARED
# 25832             INSTRUMENTAL - ULTRA VIOLET ABSORPTION
#
#                                          Local Site Name  \
# 58201                                       Simmons Park
# 47948                                      Elizabeth Lab
# 47612                                FORT COLLINS - WEST
# 43962  TRINITY ST MARKS - Gordy Howe International Br...
# 25832                                      Auburn-Atwood
#
#                                      Address  State Name   County Name  \
# 58201             2401 19th Avenue Northwest     Florida  Hillsborough
# 47948  NJ Turnpike Interchange 13 Toll Plaza  New Jersey         Union
# 47612                     3416 LA PORTE AVE.    Colorado       Larimer
# 43962       9191 W FORT ST (Detroit-Trinity)    Michigan         Wayne
# 25832            11645 Atwood Street, Auburn  California        Placer
#
#           City Name                                CBSA Name  \
# 58201        Ruskin      Tampa-St. Petersburg-Clearwater, FL
# 47948     Elizabeth    New York-Newark-Jersey City, NY-NJ-PA
# 47612  Fort Collins                         Fort Collins, CO
# 43962       Detroit              Detroit-Warren-Dearborn, MI
# 25832        Auburn  Sacramento--Roseville--Arden-Arcade, CA
#
#        Date of Last Change
# 58201           2025-11-17
# 47948           2025-09-30
# 47612           2025-11-07
# 43962           2025-09-17
# 25832           2025-10-23
#
# [5 rows x 29 columns]

# %%
print(all_param.iloc[:, 10:].head())
# Out:
#   Pollutant Standard  Date Local   Units of Measure Event Type  \
# 0  Ozone 8-hour 2015  2025-02-28  Parts per million        NaN
# 1  Ozone 8-hour 2015  2025-03-01  Parts per million        NaN
# 2  Ozone 8-hour 2015  2025-03-02  Parts per million        NaN
# 3  Ozone 8-hour 2015  2025-03-03  Parts per million        NaN
# 4  Ozone 8-hour 2015  2025-03-04  Parts per million        NaN
#
#    Observation Count  Observation Percent  Arithmetic Mean  1st Max Value  \
# 0                  1                  6.0         0.006000          0.006
# 1                 17                100.0         0.050824          0.058
# 2                 17                100.0         0.038882          0.047
# 3                 17                100.0         0.042765          0.048
# 4                 17                100.0         0.046000          0.049
#
#    1st Max Hour   AQI  Method Code                             Method Name  \
# 0            23   6.0           87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION
# 1            10  61.0           87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION
# 2            10  44.0           87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION
# 3             9  44.0           87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION
# 4             9  45.0           87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION
#
#      Local Site Name                                            Address  \
# 0  FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 1  FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 2  FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 3  FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
# 4  FAIRHOPE, Alabama  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...
#
#   State Name County Name City Name                  CBSA Name  \
# 0    Alabama     Baldwin  Fairhope  Daphne-Fairhope-Foley, AL
# 1    Alabama     Baldwin  Fairhope  Daphne-Fairhope-Foley, AL
# 2    Alabama     Baldwin  Fairhope  Daphne-Fairhope-Foley, AL
# 3    Alabama     Baldwin  Fairhope  Daphne-Fairhope-Foley, AL
# 4    Alabama     Baldwin  Fairhope  Daphne-Fairhope-Foley, AL
#
#   Date of Last Change
# 0          2025-10-29
# 1          2025-10-29
# 2          2025-10-29
# 3          2025-10-29
# 4          2025-10-29

# %%
choose = ["Date Local", 'Latitude', 'Longitude', 'Sample Duration',
         'Parameter Name', 'Observation Count', "Observation Percent", 'Arithmetic Mean', '1st Max Value', '1st Max Hour', 'AQI',
          'Method Name', "State Name", "County Name", "City Name", "CBSA Name"]

# %%
all_param[choose].head()
# Out:
#    Date Local   Latitude  Longitude          Sample Duration Parameter Name  \
# 0  2025-02-28  30.497478 -87.880258  8-HR RUN AVG BEGIN HOUR          Ozone
# 1  2025-03-01  30.497478 -87.880258  8-HR RUN AVG BEGIN HOUR          Ozone
# 2  2025-03-02  30.497478 -87.880258  8-HR RUN AVG BEGIN HOUR          Ozone
# 3  2025-03-03  30.497478 -87.880258  8-HR RUN AVG BEGIN HOUR          Ozone
# 4  2025-03-04  30.497478 -87.880258  8-HR RUN AVG BEGIN HOUR          Ozone
#
#    Observation Count  Observation Percent  Arithmetic Mean  1st Max Value  \
# 0                  1                  6.0         0.006000          0.006
# 1                 17                100.0         0.050824          0.058
# 2                 17                100.0         0.038882          0.047
# 3                 17                100.0         0.042765          0.048
# 4                 17                100.0         0.046000          0.049
#
#    1st Max Hour   AQI                             Method Name State Name  \
# 0            23   6.0  INSTRUMENTAL - ULTRA VIOLET ABSORPTION    Alabama
# 1            10  61.0  INSTRUMENTAL - ULTRA VIOLET ABSORPTION    Alabama
# 2            10  44.0  INSTRUMENTAL - ULTRA VIOLET ABSORPTION    Alabama
# 3             9  44.0  INSTRUMENTAL - ULTRA VIOLET ABSORPTION    Alabama
# 4             9  45.0  INSTRUMENTAL - ULTRA VIOLET ABSORPTION    Alabama
#
#   County Name City Name                  CBSA Name
# 0     Baldwin  Fairhope  Daphne-Fairhope-Foley, AL
# 1     Baldwin  Fairhope  Daphne-Fairhope-Foley, AL
# 2     Baldwin  Fairhope  Daphne-Fairhope-Foley, AL
# 3     Baldwin  Fairhope  Daphne-Fairhope-Foley, AL
# 4     Baldwin  Fairhope  Daphne-Fairhope-Foley, AL

# %%
all_param.sort_values("CBSA Name").head()
# Out:
#         State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 124833          26           91         7           44201    1  41.995568
# 124832          26           91         7           44201    1  41.995568
# 124831          26           91         7           44201    1  41.995568
# 124830          26           91         7           44201    1  41.995568
# 124829          26           91         7           44201    1  41.995568
#
#         Longitude  Datum Parameter Name          Sample Duration  ...   AQI  \
# 124833 -83.946559  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  51.0
# 124832 -83.946559  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  74.0
# 124831 -83.946559  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  40.0
# 124830 -83.946559  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  32.0
# 124829 -83.946559  WGS84          Ozone  8-HR RUN AVG BEGIN HOUR  ...  47.0
#
#        Method Code                             Method Name  \
# 124833          87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION
# 124832          87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION
# 124831          87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION
# 124830          87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION
# 124829          87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION
#
#                                           Local Site Name  \
# 124833  6792 RAISIN CENTER HWY, LENAWEE CO.RD.COMM.OWN...
# 124832  6792 RAISIN CENTER HWY, LENAWEE CO.RD.COMM.OWN...
# 124831  6792 RAISIN CENTER HWY, LENAWEE CO.RD.COMM.OWN...
# 124830  6792 RAISIN CENTER HWY, LENAWEE CO.RD.COMM.OWN...
# 124829  6792 RAISIN CENTER HWY, LENAWEE CO.RD.COMM.OWN...
#
#                                Address  State Name  County Name  City Name  \
# 124833  6792 RAISEN CTR HWY (TECUMSEH)    Michigan      Lenawee   Tecumseh
# 124832  6792 RAISEN CTR HWY (TECUMSEH)    Michigan      Lenawee   Tecumseh
# 124831  6792 RAISEN CTR HWY (TECUMSEH)    Michigan      Lenawee   Tecumseh
# 124830  6792 RAISEN CTR HWY (TECUMSEH)    Michigan      Lenawee   Tecumseh
# 124829  6792 RAISEN CTR HWY (TECUMSEH)    Michigan      Lenawee   Tecumseh
#
#          CBSA Name  Date of Last Change
# 124833  Adrian, MI           2025-11-14
# 124832  Adrian, MI           2025-11-14
# 124831  Adrian, MI           2025-11-14
# 124830  Adrian, MI           2025-11-14
# 124829  Adrian, MI           2025-11-14
#
# [5 rows x 29 columns]

# %%
all_param[all_param["CBSA Name"] == 'Daphne-Fairhope-Foley, AL']
# Out:
#      State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0             1            3        10           44201    1  30.497478
# 1             1            3        10           44201    1  30.497478
# 2             1            3        10           44201    1  30.497478
# 3             1            3        10           44201    1  30.497478
# 4             1            3        10           44201    1  30.497478
# ..          ...          ...       ...             ...  ...        ...
# 178           1            3        10           44201    1  30.497478
# 179           1            3        10           44201    1  30.497478
# 180           1            3        10           44201    1  30.497478
# 181           1            3        10           44201    1  30.497478
# 182           1            3        10           44201    1  30.497478
#
#      Longitude  Datum Parameter Name          Sample Duration  ...   AQI  \
# 0   -87.880258  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR  ...   6.0
# 1   -87.880258  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR  ...  61.0
# 2   -87.880258  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR  ...  44.0
# 3   -87.880258  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR  ...  44.0
# 4   -87.880258  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR  ...  45.0
# ..         ...    ...            ...                      ...  ...   ...
# 178 -87.880258  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR  ...  39.0
# 179 -87.880258  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR  ...  51.0
# 180 -87.880258  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR  ...  23.0
# 181 -87.880258  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR  ...  31.0
# 182 -87.880258  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR  ...  34.0
#
#     Method Code                             Method Name    Local Site Name  \
# 0            87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  FAIRHOPE, Alabama
# 1            87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  FAIRHOPE, Alabama
# 2            87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  FAIRHOPE, Alabama
# 3            87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  FAIRHOPE, Alabama
# 4            87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  FAIRHOPE, Alabama
# ..          ...                                     ...                ...
# 178          87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  FAIRHOPE, Alabama
# 179          87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  FAIRHOPE, Alabama
# 180          87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  FAIRHOPE, Alabama
# 181          87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  FAIRHOPE, Alabama
# 182          87  INSTRUMENTAL - ULTRA VIOLET ABSORPTION  FAIRHOPE, Alabama
#
#                                                Address  State Name  \
# 0    FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...     Alabama
# 1    FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...     Alabama
# 2    FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...     Alabama
# 3    FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...     Alabama
# 4    FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...     Alabama
# ..                                                 ...         ...
# 178  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...     Alabama
# 179  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...     Alabama
# 180  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...     Alabama
# 181  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...     Alabama
# 182  FAIRHOPE HIGH SCHOOL, 1 PIRATE DRIVE, FAIRHOPE...     Alabama
#
#      County Name  City Name                  CBSA Name  Date of Last Change
# 0        Baldwin   Fairhope  Daphne-Fairhope-Foley, AL           2025-10-29
# 1        Baldwin   Fairhope  Daphne-Fairhope-Foley, AL           2025-10-29
# 2        Baldwin   Fairhope  Daphne-Fairhope-Foley, AL           2025-10-29
# 3        Baldwin   Fairhope  Daphne-Fairhope-Foley, AL           2025-10-29
# 4        Baldwin   Fairhope  Daphne-Fairhope-Foley, AL           2025-10-29
# ..           ...        ...                        ...                  ...
# 178      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL           2025-10-29
# 179      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL           2025-10-29
# 180      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL           2025-10-29
# 181      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL           2025-10-29
# 182      Baldwin   Fairhope  Daphne-Fairhope-Foley, AL           2025-10-29
#
# [183 rows x 29 columns]

# %%
all_param.sort_values("CBSA Name").to_csv("all_parameters_daily.csv", index=False)

# %%
sorted = all_param.sort_values("CBSA Name")
sorted[sorted["CBSA Name"] == "Yuba City, CA"].sort_values(by="Date Local", ascending=True)[["Date Local", "Local Site Name"]]
# Out:
#        Date Local           Local Site Name
# 38383  2025-01-01                 Yuba City
# 16383  2025-01-01                 Yuba City
# 16384  2025-01-02                 Yuba City
# 38384  2025-01-02                 Yuba City
# 38385  2025-01-03                 Yuba City
# ...           ...                       ...
# 38593  2025-07-30                 Yuba City
# 38716  2025-07-30  Sutter Buttes (seasonal)
# 16594  2025-07-31                 Yuba City
# 38594  2025-07-31                 Yuba City
# 38717  2025-07-31  Sutter Buttes (seasonal)
#
# [547 rows x 2 columns]

# %%
set(sorted[sorted["CBSA Name"] == "Yuba City, CA"]["Date Local"])
# Out:
# {'2025-01-01',
#  '2025-01-02',
#  '2025-01-03',
#  '2025-01-04',
#  '2025-01-05',
#  '2025-01-06',
#  '2025-01-07',
#  '2025-01-08',
#  '2025-01-09',
#  '2025-01-10',
#  '2025-01-11',
#  '2025-01-12',
#  '2025-01-13',
#  '2025-01-14',
#  '2025-01-15',
#  '2025-01-16',
#  '2025-01-17',
#  '2025-01-18',
#  '2025-01-19',
#  '2025-01-20',
#  '2025-01-21',
#  '2025-01-22',
#  '2025-01-23',
#  '2025-01-24',
#  '2025-01-25',
#  '2025-01-26',
#  '2025-01-27',
#  '2025-01-28',
#  '2025-01-29',
#  '2025-01-30',
#  '2025-01-31',
#  '2025-02-01',
#  '2025-02-02',
#  '2025-02-03',
#  '2025-02-04',
#  '2025-02-05',
#  '2025-02-06',
#  '2025-02-07',
#  '2025-02-08',
#  '2025-02-09',
#  '2025-02-10',
#  '2025-02-11',
#  '2025-02-12',
#  '2025-02-13',
#  '2025-02-14',
#  '2025-02-15',
#  '2025-02-16',
#  '2025-02-17',
#  '2025-02-18',
#  '2025-02-19',
#  '2025-02-20',
#  '2025-02-21',
#  '2025-02-22',
#  '2025-02-23',
#  '2025-02-24',
#  '2025-02-25',
#  '2025-02-26',
#  '2025-02-27',
#  '2025-02-28',
#  '2025-03-01',
#  '2025-03-02',
#  '2025-03-03',
#  '2025-03-04',
#  '2025-03-05',
#  '2025-03-06',
#  '2025-03-07',
#  '2025-03-08',
#  '2025-03-09',
#  '2025-03-10',
#  '2025-03-11',
#  '2025-03-12',
#  '2025-03-13',
#  '2025-03-14',
#  '2025-03-15',
#  '2025-03-16',
#  '2025-03-17',
#  '2025-03-18',
#  '2025-03-19',
#  '2025-03-20',
#  '2025-03-21',
#  '2025-03-22',
#  '2025-03-23',
#  '2025-03-24',
#  '2025-03-25',
#  '2025-03-26',
#  '2025-03-27',
#  '2025-03-28',
#  '2025-03-29',
#  '2025-03-30',
#  '2025-03-31',
#  '2025-04-01',
#  '2025-04-02',
#  '2025-04-03',
#  '2025-04-04',
#  '2025-04-05',
#  '2025-04-06',
#  '2025-04-07',
#  '2025-04-08',
#  '2025-04-09',
#  '2025-04-10',
#  '2025-04-11',
#  '2025-04-12',
#  '2025-04-13',
#  '2025-04-14',
#  '2025-04-15',
#  '2025-04-16',
#  '2025-04-17',
#  '2025-04-18',
#  '2025-04-19',
#  '2025-04-20',
#  '2025-04-21',
#  '2025-04-22',
#  '2025-04-23',
#  '2025-04-24',
#  '2025-04-25',
#  '2025-04-26',
#  '2025-04-27',
#  '2025-04-28',
#  '2025-04-29',
#  '2025-04-30',
#  '2025-05-01',
#  '2025-05-02',
#  '2025-05-03',
#  '2025-05-04',
#  '2025-05-05',
#  '2025-05-06',
#  '2025-05-07',
#  '2025-05-08',
#  '2025-05-09',
#  '2025-05-10',
#  '2025-05-11',
#  '2025-05-12',
#  '2025-05-13',
#  '2025-05-14',
#  '2025-05-15',
#  '2025-05-16',
#  '2025-05-17',
#  '2025-05-18',
#  '2025-05-19',
#  '2025-05-20',
#  '2025-05-21',
#  '2025-05-22',
#  '2025-05-23',
#  '2025-05-24',
#  '2025-05-25',
#  '2025-05-26',
#  '2025-05-27',
#  '2025-05-28',
#  '2025-05-29',
#  '2025-05-30',
#  '2025-05-31',
#  '2025-06-01',
#  '2025-06-02',
#  '2025-06-03',
#  '2025-06-04',
#  '2025-06-05',
#  '2025-06-06',
#  '2025-06-07',
#  '2025-06-08',
#  '2025-06-09',
#  '2025-06-10',
#  '2025-06-11',
#  '2025-06-12',
#  '2025-06-13',
#  '2025-06-14',
#  '2025-06-15',
#  '2025-06-16',
#  '2025-06-17',
#  '2025-06-18',
#  '2025-06-19',
#  '2025-06-20',
#  '2025-06-21',
#  '2025-06-22',
#  '2025-06-23',
#  '2025-06-24',
#  '2025-06-25',
#  '2025-06-26',
#  '2025-06-27',
#  '2025-06-28',
#  '2025-06-29',
#  '2025-06-30',
#  '2025-07-01',
#  '2025-07-02',
#  '2025-07-03',
#  '2025-07-04',
#  '2025-07-05',
#  '2025-07-06',
#  '2025-07-07',
#  '2025-07-08',
#  '2025-07-09',
#  '2025-07-10',
#  '2025-07-11',
#  '2025-07-12',
#  '2025-07-13',
#  '2025-07-14',
#  '2025-07-15',
#  '2025-07-16',
#  '2025-07-17',
#  '2025-07-18',
#  '2025-07-19',
#  '2025-07-20',
#  '2025-07-21',
#  '2025-07-22',
#  '2025-07-23',
#  '2025-07-24',
#  '2025-07-25',
#  '2025-07-26',
#  '2025-07-27',
#  '2025-07-28',
#  '2025-07-29',
#  '2025-07-30',
#  '2025-07-31'}
